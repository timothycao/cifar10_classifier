# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/deep-learning-spring-2025-project-1/cifar_test_nolabel.pkl
# /kaggle/input/deep-learning-spring-2025-project-1/cifar-10-python/cifar-10-batches-py/data_batch_1
# /kaggle/input/deep-learning-spring-2025-project-1/cifar-10-python/cifar-10-batches-py/data_batch_2
# /kaggle/input/deep-learning-spring-2025-project-1/cifar-10-python/cifar-10-batches-py/batches.meta
# /kaggle/input/deep-learning-spring-2025-project-1/cifar-10-python/cifar-10-batches-py/test_batch
# /kaggle/input/deep-learning-spring-2025-project-1/cifar-10-python/cifar-10-batches-py/data_batch_3
# /kaggle/input/deep-learning-spring-2025-project-1/cifar-10-python/cifar-10-batches-py/data_batch_5
# /kaggle/input/deep-learning-spring-2025-project-1/cifar-10-python/cifar-10-batches-py/data_batch_4
# /kaggle/input/deep-learning-spring-2025-project-1/cifar-10-python/cifar-10-batches-py/readme.html

# %%
# !git clone https://github.com/timothycao/cifar10_classifier.git
# %cd cifar10_classifier
# Out:
# Cloning into 'cifar10_classifier'...
# remote: Enumerating objects: 84, done.
# remote: Counting objects: 100% (84/84), done.
# remote: Compressing objects: 100% (57/57), done.
# remote: Total 84 (delta 46), reused 62 (delta 24), pack-reused 0 (from 0)
# Receiving objects: 100% (84/84), 21.73 KiB | 4.35 MiB/s, done.
# Resolving deltas: 100% (46/46), done.
# /kaggle/working/cifar10_classifier

# %%
import torch.optim as optim
import torchvision.transforms as transforms
from model import create_model
from train import main as train
from inference import main as inference


# Model parameters
MODEL_NAME = 'ResNetCustom'
BLOCK_TYPE = 'basic'
NUM_BLOCKS_PER_LAYER = [2, 2, 2, 2]
NUM_CHANNELS_PER_LAYER = [42, 84, 168, 336]
KERNEL_SIZE_PER_LAYER = [3, 3, 3, 3]
SKIP_KERNEL_SIZE_PER_LAYER = [1, 1, 1, 1]
EXPANSION = 1
POOL_SIZE = 1


# Training parameters
EPOCHS = 100
TRAIN_BATCH_SIZE = 128
TEST_BATCH_SIZE = 100
AUGMENTATIONS = [
    transforms.RandomHorizontalFlip(p=0.5),
    transforms.RandomCrop(32, padding=4)
]
SAVE_MODE = 'best'  # Options: 'best', 'every'
SAVE_EVERY_N = 1

# Initialize model
try:
    model = create_model(
        name=MODEL_NAME,
        block_type=BLOCK_TYPE,
        blocks_per_layer=NUM_BLOCKS_PER_LAYER,
        channels_per_layer=NUM_CHANNELS_PER_LAYER,
        kernels_per_layer=KERNEL_SIZE_PER_LAYER,
        skip_kernels_per_layer=SKIP_KERNEL_SIZE_PER_LAYER,
        expansion=EXPANSION,
        pool_size=POOL_SIZE
    )
    print('Total model parameters:', sum(p.numel() for p in model.parameters() if p.requires_grad))
except AssertionError as e:
    print(f'Failed to create model: {e}')
    exit(1)
# Out:
# Total model parameters: 4815940

# %%
# Train model
try:
    # Define optimizer
    OPTIMIZER = optim.SGD(model.parameters(), lr=0.01, momentum=0.9, weight_decay=5e-4)
    
    # Define scheduler
    SCHEDULER = optim.lr_scheduler.CosineAnnealingLR(OPTIMIZER, T_max=EPOCHS)
    
    # If no scheduler, set to None
    SCHEDULER = SCHEDULER if 'SCHEDULER' in locals() and SCHEDULER is not None else None

    # train(model, EPOCHS)
    train(model, EPOCHS, train_batch_size=TRAIN_BATCH_SIZE, test_batch_size=TEST_BATCH_SIZE, augmentations=AUGMENTATIONS,
          optimizer=OPTIMIZER, scheduler=SCHEDULER, save=SAVE_MODE, every_n=SAVE_EVERY_N)
except (ValueError, TypeError) as e:
    print(f'Training failed: {e}')
    exit(1)
# Out:
# Total model parameters: 4815940
# Loading data...
# Preprocessing pipeline:
#  Compose(
#     RandomHorizontalFlip(p=0.5)
#     RandomCrop(size=(32, 32), padding=4)
#     ToTensor()
#     Normalize(mean=(0.4914, 0.4822, 0.4465), std=(0.2023, 0.1994, 0.201))
# )
# Files already downloaded and verified
# Files already downloaded and verified
# Initializing model...
# Training model...
#
# Epoch: 1/100      LR: 0.01000
# TRAIN: Loss: 1.47 Acc: 45.99%
# TEST:  Loss: 1.72 Acc: 46.12%
#
# Epoch: 2/100      LR: 0.01000
# TRAIN: Loss: 0.98 Acc: 65.11%
# TEST:  Loss: 1.05 Acc: 64.66%
#
# Epoch: 3/100      LR: 0.00999
# TRAIN: Loss: 0.76 Acc: 73.29%
# TEST:  Loss: 0.78 Acc: 73.93%
#
# Epoch: 4/100      LR: 0.00998
# TRAIN: Loss: 0.64 Acc: 77.76%
# TEST:  Loss: 0.72 Acc: 75.44%
#
# Epoch: 5/100      LR: 0.00996
# TRAIN: Loss: 0.56 Acc: 80.35%
# TEST:  Loss: 0.59 Acc: 80.45%
#
# Epoch: 6/100      LR: 0.00994
# TRAIN: Loss: 0.50 Acc: 82.45%
# TEST:  Loss: 0.70 Acc: 77.32%
#
# Epoch: 7/100      LR: 0.00991
# TRAIN: Loss: 0.46 Acc: 83.97%
# TEST:  Loss: 0.51 Acc: 83.26%
#
# Epoch: 8/100      LR: 0.00988
# TRAIN: Loss: 0.42 Acc: 85.35%
# TEST:  Loss: 0.67 Acc: 78.16%
#
# Epoch: 9/100      LR: 0.00984
# TRAIN: Loss: 0.40 Acc: 86.23%
# TEST:  Loss: 0.48 Acc: 84.10%
#
# Epoch: 10/100     LR: 0.00980
# TRAIN: Loss: 0.36 Acc: 87.42%
# TEST:  Loss: 0.52 Acc: 83.35%
#
# Epoch: 11/100     LR: 0.00976
# TRAIN: Loss: 0.34 Acc: 88.07%
# TEST:  Loss: 0.44 Acc: 85.43%
#
# Epoch: 12/100     LR: 0.00970
# TRAIN: Loss: 0.32 Acc: 88.74%
# TEST:  Loss: 0.52 Acc: 83.09%
#
# Epoch: 13/100     LR: 0.00965
# TRAIN: Loss: 0.30 Acc: 89.48%
# TEST:  Loss: 0.41 Acc: 86.65%
#
# Epoch: 14/100     LR: 0.00959
# TRAIN: Loss: 0.28 Acc: 90.21%
# TEST:  Loss: 0.46 Acc: 85.42%
#
# Epoch: 15/100     LR: 0.00952
# TRAIN: Loss: 0.27 Acc: 90.56%
# TEST:  Loss: 0.42 Acc: 85.87%
#
# Epoch: 16/100     LR: 0.00946
# TRAIN: Loss: 0.26 Acc: 90.82%
# TEST:  Loss: 0.42 Acc: 86.56%
#
# Epoch: 17/100     LR: 0.00938
# TRAIN: Loss: 0.24 Acc: 91.35%
# TEST:  Loss: 0.40 Acc: 86.97%
#
# Epoch: 18/100     LR: 0.00930
# TRAIN: Loss: 0.23 Acc: 92.04%
# TEST:  Loss: 0.42 Acc: 86.68%
#
# Epoch: 19/100     LR: 0.00922
# TRAIN: Loss: 0.22 Acc: 92.34%
# TEST:  Loss: 0.39 Acc: 87.75%
#
# Epoch: 20/100     LR: 0.00914
# TRAIN: Loss: 0.21 Acc: 92.79%
# TEST:  Loss: 0.36 Acc: 88.57%
#
# Epoch: 21/100     LR: 0.00905
# TRAIN: Loss: 0.20 Acc: 92.91%
# TEST:  Loss: 0.41 Acc: 87.15%
#
# Epoch: 22/100     LR: 0.00895
# TRAIN: Loss: 0.19 Acc: 93.37%
# TEST:  Loss: 0.41 Acc: 87.12%
#
# Epoch: 23/100     LR: 0.00885
# TRAIN: Loss: 0.18 Acc: 93.82%
# TEST:  Loss: 0.37 Acc: 88.08%
#
# Epoch: 24/100     LR: 0.00875
# TRAIN: Loss: 0.17 Acc: 93.98%
# TEST:  Loss: 0.36 Acc: 88.93%
#
# Epoch: 25/100     LR: 0.00864
# TRAIN: Loss: 0.16 Acc: 94.45%
# TEST:  Loss: 0.49 Acc: 85.79%
#
# Epoch: 26/100     LR: 0.00854
# TRAIN: Loss: 0.16 Acc: 94.32%
# TEST:  Loss: 0.35 Acc: 89.30%
#
# Epoch: 27/100     LR: 0.00842
# TRAIN: Loss: 0.15 Acc: 94.86%
# TEST:  Loss: 0.37 Acc: 89.04%
#
# Epoch: 28/100     LR: 0.00831
# TRAIN: Loss: 0.14 Acc: 95.13%
# TEST:  Loss: 0.37 Acc: 88.72%
#
# Epoch: 29/100     LR: 0.00819
# TRAIN: Loss: 0.14 Acc: 95.19%
# TEST:  Loss: 0.34 Acc: 89.55%
#
# Epoch: 30/100     LR: 0.00806
# TRAIN: Loss: 0.13 Acc: 95.41%
# TEST:  Loss: 0.40 Acc: 88.64%
#
# Epoch: 31/100     LR: 0.00794
# TRAIN: Loss: 0.12 Acc: 95.67%
# TEST:  Loss: 0.35 Acc: 89.32%
#
# Epoch: 32/100     LR: 0.00781
# TRAIN: Loss: 0.12 Acc: 95.83%
# TEST:  Loss: 0.48 Acc: 86.24%
#
# Epoch: 33/100     LR: 0.00768
# TRAIN: Loss: 0.11 Acc: 96.11%
# TEST:  Loss: 0.42 Acc: 88.29%
#
# Epoch: 34/100     LR: 0.00755
# TRAIN: Loss: 0.10 Acc: 96.38%
# TEST:  Loss: 0.38 Acc: 89.00%
#
# Epoch: 35/100     LR: 0.00741
# TRAIN: Loss: 0.10 Acc: 96.43%
# TEST:  Loss: 0.40 Acc: 88.98%
#
# Epoch: 36/100     LR: 0.00727
# TRAIN: Loss: 0.09 Acc: 96.65%
# TEST:  Loss: 0.37 Acc: 89.49%
#
# Epoch: 37/100     LR: 0.00713
# TRAIN: Loss: 0.09 Acc: 96.94%
# TEST:  Loss: 0.34 Acc: 90.12%
#
# Epoch: 38/100     LR: 0.00699
# TRAIN: Loss: 0.08 Acc: 97.08%
# TEST:  Loss: 0.41 Acc: 88.89%
#
# Epoch: 39/100     LR: 0.00684
# TRAIN: Loss: 0.09 Acc: 96.97%
# TEST:  Loss: 0.34 Acc: 90.32%
#
# Epoch: 40/100     LR: 0.00669
# TRAIN: Loss: 0.08 Acc: 97.40%
# TEST:  Loss: 0.33 Acc: 90.59%
#
# Epoch: 41/100     LR: 0.00655
# TRAIN: Loss: 0.07 Acc: 97.43%
# TEST:  Loss: 0.32 Acc: 91.08%
#
# Epoch: 42/100     LR: 0.00639
# TRAIN: Loss: 0.07 Acc: 97.60%
# TEST:  Loss: 0.33 Acc: 90.72%
#
# Epoch: 43/100     LR: 0.00624
# TRAIN: Loss: 0.07 Acc: 97.71%
# TEST:  Loss: 0.33 Acc: 90.95%
#
# Epoch: 44/100     LR: 0.00609
# TRAIN: Loss: 0.06 Acc: 98.08%
# TEST:  Loss: 0.32 Acc: 90.96%
#
# Epoch: 45/100     LR: 0.00594
# TRAIN: Loss: 0.05 Acc: 98.21%
# TEST:  Loss: 0.34 Acc: 90.74%
#
# Epoch: 46/100     LR: 0.00578
# TRAIN: Loss: 0.05 Acc: 98.22%
# TEST:  Loss: 0.34 Acc: 91.08%
#
# Epoch: 47/100     LR: 0.00563
# TRAIN: Loss: 0.05 Acc: 98.22%
# TEST:  Loss: 0.33 Acc: 91.09%
#
# Epoch: 48/100     LR: 0.00547
# TRAIN: Loss: 0.05 Acc: 98.36%
# TEST:  Loss: 0.32 Acc: 91.37%
#
# Epoch: 49/100     LR: 0.00531
# TRAIN: Loss: 0.05 Acc: 98.40%
# TEST:  Loss: 0.30 Acc: 91.73%
#
# Epoch: 50/100     LR: 0.00516
# TRAIN: Loss: 0.04 Acc: 98.56%
# TEST:  Loss: 0.33 Acc: 90.91%
#
# Epoch: 51/100     LR: 0.00500
# TRAIN: Loss: 0.04 Acc: 98.77%
# TEST:  Loss: 0.32 Acc: 91.57%
#
# Epoch: 52/100     LR: 0.00484
# TRAIN: Loss: 0.03 Acc: 98.91%
# TEST:  Loss: 0.30 Acc: 91.91%
#
# Epoch: 53/100     LR: 0.00469
# TRAIN: Loss: 0.03 Acc: 99.08%
# TEST:  Loss: 0.33 Acc: 91.18%
#
# Epoch: 54/100     LR: 0.00453
# TRAIN: Loss: 0.03 Acc: 99.09%
# TEST:  Loss: 0.32 Acc: 91.73%
#
# Epoch: 55/100     LR: 0.00437
# TRAIN: Loss: 0.03 Acc: 99.13%
# TEST:  Loss: 0.31 Acc: 91.96%
#
# Epoch: 56/100     LR: 0.00422
# TRAIN: Loss: 0.02 Acc: 99.28%
# TEST:  Loss: 0.32 Acc: 91.90%
#
# Epoch: 57/100     LR: 0.00406
# TRAIN: Loss: 0.02 Acc: 99.43%
# TEST:  Loss: 0.29 Acc: 92.47%
#
# Epoch: 58/100     LR: 0.00391
# TRAIN: Loss: 0.02 Acc: 99.51%
# TEST:  Loss: 0.33 Acc: 91.76%
#
# Epoch: 59/100     LR: 0.00376
# TRAIN: Loss: 0.02 Acc: 99.42%
# TEST:  Loss: 0.30 Acc: 91.92%
#
# Epoch: 60/100     LR: 0.00361
# TRAIN: Loss: 0.02 Acc: 99.49%
# TEST:  Loss: 0.29 Acc: 92.18%
#
# Epoch: 61/100     LR: 0.00345
# TRAIN: Loss: 0.02 Acc: 99.58%
# TEST:  Loss: 0.28 Acc: 92.68%
#
# Epoch: 62/100     LR: 0.00331
# TRAIN: Loss: 0.01 Acc: 99.64%
# TEST:  Loss: 0.30 Acc: 92.15%
#
# Epoch: 63/100     LR: 0.00316
# TRAIN: Loss: 0.01 Acc: 99.76%
# TEST:  Loss: 0.30 Acc: 92.49%
#
# Epoch: 64/100     LR: 0.00301
# TRAIN: Loss: 0.01 Acc: 99.75%
# TEST:  Loss: 0.29 Acc: 92.31%
#
# Epoch: 65/100     LR: 0.00287
# TRAIN: Loss: 0.01 Acc: 99.80%
# TEST:  Loss: 0.28 Acc: 92.71%
#
# Epoch: 66/100     LR: 0.00273
# TRAIN: Loss: 0.01 Acc: 99.83%
# TEST:  Loss: 0.29 Acc: 92.80%
#
# Epoch: 67/100     LR: 0.00259
# TRAIN: Loss: 0.01 Acc: 99.86%
# TEST:  Loss: 0.28 Acc: 92.62%
#
# Epoch: 68/100     LR: 0.00245
# TRAIN: Loss: 0.01 Acc: 99.85%
# TEST:  Loss: 0.29 Acc: 92.56%
#
# Epoch: 69/100     LR: 0.00232
# TRAIN: Loss: 0.01 Acc: 99.86%
# TEST:  Loss: 0.28 Acc: 92.83%
#
# Epoch: 70/100     LR: 0.00219
# TRAIN: Loss: 0.01 Acc: 99.90%
# TEST:  Loss: 0.28 Acc: 92.87%
#
# Epoch: 71/100     LR: 0.00206
# TRAIN: Loss: 0.01 Acc: 99.89%
# TEST:  Loss: 0.28 Acc: 92.90%
#
# Epoch: 72/100     LR: 0.00194
# TRAIN: Loss: 0.01 Acc: 99.92%
# TEST:  Loss: 0.27 Acc: 93.01%
#
# Epoch: 73/100     LR: 0.00181
# TRAIN: Loss: 0.00 Acc: 99.93%
# TEST:  Loss: 0.27 Acc: 93.06%
#
# Epoch: 74/100     LR: 0.00169
# TRAIN: Loss: 0.00 Acc: 99.94%
# TEST:  Loss: 0.27 Acc: 93.15%
#
# Epoch: 75/100     LR: 0.00158
# TRAIN: Loss: 0.00 Acc: 99.95%
# TEST:  Loss: 0.27 Acc: 93.24%
#
# Epoch: 76/100     LR: 0.00146
# TRAIN: Loss: 0.00 Acc: 99.96%
# TEST:  Loss: 0.27 Acc: 93.17%
#
# Epoch: 77/100     LR: 0.00136
# TRAIN: Loss: 0.00 Acc: 99.96%
# TEST:  Loss: 0.27 Acc: 93.05%
#
# Epoch: 78/100     LR: 0.00125
# TRAIN: Loss: 0.00 Acc: 99.95%
# TEST:  Loss: 0.27 Acc: 93.24%
#
# Epoch: 79/100     LR: 0.00115
# TRAIN: Loss: 0.00 Acc: 99.98%
# TEST:  Loss: 0.26 Acc: 93.24%
#
# Epoch: 80/100     LR: 0.00105
# TRAIN: Loss: 0.00 Acc: 99.97%
# TEST:  Loss: 0.27 Acc: 93.10%
#
# Epoch: 81/100     LR: 0.00095
# TRAIN: Loss: 0.00 Acc: 99.97%
# TEST:  Loss: 0.27 Acc: 93.29%
#
# Epoch: 82/100     LR: 0.00086
# TRAIN: Loss: 0.00 Acc: 99.96%
# TEST:  Loss: 0.27 Acc: 93.11%
#
# Epoch: 83/100     LR: 0.00078
# TRAIN: Loss: 0.00 Acc: 99.97%
# TEST:  Loss: 0.27 Acc: 93.31%
#
# Epoch: 84/100     LR: 0.00070
# TRAIN: Loss: 0.00 Acc: 99.98%
# TEST:  Loss: 0.27 Acc: 93.25%
#
# Epoch: 85/100     LR: 0.00062
# TRAIN: Loss: 0.00 Acc: 99.98%
# TEST:  Loss: 0.26 Acc: 93.27%
#
# Epoch: 86/100     LR: 0.00054
# TRAIN: Loss: 0.00 Acc: 99.98%
# TEST:  Loss: 0.26 Acc: 93.33%
#
# Epoch: 87/100     LR: 0.00048
# TRAIN: Loss: 0.00 Acc: 99.98%
# TEST:  Loss: 0.27 Acc: 93.22%
#
# Epoch: 88/100     LR: 0.00041
# TRAIN: Loss: 0.00 Acc: 99.98%
# TEST:  Loss: 0.27 Acc: 93.28%
#
# Epoch: 89/100     LR: 0.00035
# TRAIN: Loss: 0.00 Acc: 99.98%
# TEST:  Loss: 0.26 Acc: 93.24%
#
# Epoch: 90/100     LR: 0.00030
# TRAIN: Loss: 0.00 Acc: 99.99%
# TEST:  Loss: 0.26 Acc: 93.15%
#
# Epoch: 91/100     LR: 0.00024
# TRAIN: Loss: 0.00 Acc: 99.99%
# TEST:  Loss: 0.26 Acc: 93.29%
#
# Epoch: 92/100     LR: 0.00020
# TRAIN: Loss: 0.00 Acc: 99.98%
# TEST:  Loss: 0.26 Acc: 93.23%
#
# Epoch: 93/100     LR: 0.00016
# TRAIN: Loss: 0.00 Acc: 100.00%
# TEST:  Loss: 0.26 Acc: 93.31%
#
# Epoch: 94/100     LR: 0.00012
# TRAIN: Loss: 0.00 Acc: 99.98%
# TEST:  Loss: 0.26 Acc: 93.24%
#
# Epoch: 95/100     LR: 0.00009
# TRAIN: Loss: 0.00 Acc: 99.99%
# TEST:  Loss: 0.26 Acc: 93.24%
#
# Epoch: 96/100     LR: 0.00006
# TRAIN: Loss: 0.00 Acc: 99.97%
# TEST:  Loss: 0.26 Acc: 93.30%
#
# Epoch: 97/100     LR: 0.00004
# TRAIN: Loss: 0.00 Acc: 99.98%
# TEST:  Loss: 0.26 Acc: 93.22%
#
# Epoch: 98/100     LR: 0.00002
# TRAIN: Loss: 0.00 Acc: 99.98%
# TEST:  Loss: 0.26 Acc: 93.31%
#
# Epoch: 99/100     LR: 0.00001
# TRAIN: Loss: 0.00 Acc: 99.98%
# TEST:  Loss: 0.26 Acc: 93.25%
#
# Epoch: 100/100    LR: 0.00000
# TRAIN: Loss: 0.00 Acc: 99.98%
# TEST:  Loss: 0.26 Acc: 93.34%
# Model saved as ResNetCustom_epoch100_acc93.pth
# Training complete

# %%
# Run inference
try:
    inference('ResNetCustom_epoch100_acc93.pth')
except FileNotFoundError as e:
    print(f'Inference failed: {e}')
# Out:
# Loading data...
# Loading model...
# Running inference...
# Predictions saved as ResNetCustom_epoch100_acc93.csv
