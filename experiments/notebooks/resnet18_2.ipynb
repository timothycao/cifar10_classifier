# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/deep-learning-spring-2025-project-1/cifar_test_nolabel.pkl
# /kaggle/input/deep-learning-spring-2025-project-1/cifar-10-python/cifar-10-batches-py/data_batch_1
# /kaggle/input/deep-learning-spring-2025-project-1/cifar-10-python/cifar-10-batches-py/data_batch_2
# /kaggle/input/deep-learning-spring-2025-project-1/cifar-10-python/cifar-10-batches-py/batches.meta
# /kaggle/input/deep-learning-spring-2025-project-1/cifar-10-python/cifar-10-batches-py/test_batch
# /kaggle/input/deep-learning-spring-2025-project-1/cifar-10-python/cifar-10-batches-py/data_batch_3
# /kaggle/input/deep-learning-spring-2025-project-1/cifar-10-python/cifar-10-batches-py/data_batch_5
# /kaggle/input/deep-learning-spring-2025-project-1/cifar-10-python/cifar-10-batches-py/data_batch_4
# /kaggle/input/deep-learning-spring-2025-project-1/cifar-10-python/cifar-10-batches-py/readme.html

# %%
# !git clone https://github.com/timothycao/cifar10_classifier.git
# %cd cifar10_classifier
# Out:
# Cloning into 'cifar10_classifier'...
# remote: Enumerating objects: 84, done.
# remote: Counting objects: 100% (84/84), done.
# remote: Compressing objects: 100% (57/57), done.
# remote: Total 84 (delta 46), reused 62 (delta 24), pack-reused 0 (from 0)
# Receiving objects: 100% (84/84), 21.73 KiB | 5.43 MiB/s, done.
# Resolving deltas: 100% (46/46), done.
# /kaggle/working/cifar10_classifier

# %%
import torch.optim as optim
import torchvision.transforms as transforms
from model import create_model
from train import main as train
from inference import main as inference


# Model parameters
MODEL_NAME = 'ResNetCustom'
BLOCK_TYPE = 'basic'
NUM_BLOCKS_PER_LAYER = [2, 2, 2, 2]
NUM_CHANNELS_PER_LAYER = [42, 84, 168, 336]
KERNEL_SIZE_PER_LAYER = [3, 3, 3, 3]
SKIP_KERNEL_SIZE_PER_LAYER = [1, 1, 1, 1]
EXPANSION = 1
POOL_SIZE = 1


# Training parameters
EPOCHS = 100
TRAIN_BATCH_SIZE = 128
TEST_BATCH_SIZE = 100
AUGMENTATIONS = [
    transforms.RandomHorizontalFlip(p=0.5),
    transforms.RandomCrop(32, padding=4),
    transforms.ColorJitter(brightness=0.2, contrast=0.2, saturation=0.2, hue=0.1),
    transforms.RandomAffine(degrees=10, translate=(0.1, 0.1), scale=(0.8, 1.2)),
    transforms.RandAugment(num_ops=2, magnitude=9)
]
SAVE_MODE = 'best'  # Options: 'best', 'every'
SAVE_EVERY_N = 1

# Initialize model
try:
    model = create_model(
        name=MODEL_NAME,
        block_type=BLOCK_TYPE,
        blocks_per_layer=NUM_BLOCKS_PER_LAYER,
        channels_per_layer=NUM_CHANNELS_PER_LAYER,
        kernels_per_layer=KERNEL_SIZE_PER_LAYER,
        skip_kernels_per_layer=SKIP_KERNEL_SIZE_PER_LAYER,
        expansion=EXPANSION,
        pool_size=POOL_SIZE
    )
    print('Total model parameters:', sum(p.numel() for p in model.parameters() if p.requires_grad))
except AssertionError as e:
    print(f'Failed to create model: {e}')
    exit(1)
# Out:
# Total model parameters: 4815940

# %%
# Train model
try:
    # Define optimizer
    OPTIMIZER = optim.SGD(model.parameters(), lr=0.01, momentum=0.9, weight_decay=5e-4)
    
    # Define scheduler
    SCHEDULER = optim.lr_scheduler.CosineAnnealingLR(OPTIMIZER, T_max=EPOCHS)
    
    # If no scheduler, set to None
    SCHEDULER = SCHEDULER if 'SCHEDULER' in locals() and SCHEDULER is not None else None

    # train(model, EPOCHS)
    train(model, EPOCHS, train_batch_size=TRAIN_BATCH_SIZE, test_batch_size=TEST_BATCH_SIZE, augmentations=AUGMENTATIONS,
          optimizer=OPTIMIZER, scheduler=SCHEDULER, save=SAVE_MODE, every_n=SAVE_EVERY_N)
except (ValueError, TypeError) as e:
    print(f'Training failed: {e}')
    exit(1)
# Out:
# Total model parameters: 4815940
# Loading data...
# Preprocessing pipeline:
#  Compose(
#     RandomHorizontalFlip(p=0.5)
#     RandomCrop(size=(32, 32), padding=4)
#     ColorJitter(brightness=(0.8, 1.2), contrast=(0.8, 1.2), saturation=(0.8, 1.2), hue=(-0.1, 0.1))
#     RandomAffine(degrees=[-10.0, 10.0], translate=(0.1, 0.1), scale=(0.8, 1.2))
#     RandAugment(num_ops=2, magnitude=9, num_magnitude_bins=31, interpolation=InterpolationMode.NEAREST, fill=None)
#     ToTensor()
#     Normalize(mean=(0.4914, 0.4822, 0.4465), std=(0.2023, 0.1994, 0.201))
# )
# Files already downloaded and verified
# Files already downloaded and verified
# Initializing model...
# Training model...
#
# Epoch: 1/100      LR: 0.01000
# TRAIN: Loss: 1.81 Acc: 33.15%
# TEST:  Loss: 1.63 Acc: 45.09%
#
# Epoch: 2/100      LR: 0.01000
# TRAIN: Loss: 1.39 Acc: 49.95%
# TEST:  Loss: 1.22 Acc: 58.26%
#
# Epoch: 3/100      LR: 0.00999
# TRAIN: Loss: 1.17 Acc: 58.38%
# TEST:  Loss: 1.00 Acc: 65.42%
#
# Epoch: 4/100      LR: 0.00998
# TRAIN: Loss: 1.04 Acc: 63.73%
# TEST:  Loss: 0.78 Acc: 72.89%
#
# Epoch: 5/100      LR: 0.00996
# TRAIN: Loss: 0.94 Acc: 66.93%
# TEST:  Loss: 0.80 Acc: 72.39%
#
# Epoch: 6/100      LR: 0.00994
# TRAIN: Loss: 0.88 Acc: 69.33%
# TEST:  Loss: 0.67 Acc: 77.73%
#
# Epoch: 7/100      LR: 0.00991
# TRAIN: Loss: 0.83 Acc: 70.81%
# TEST:  Loss: 0.63 Acc: 78.42%
#
# Epoch: 8/100      LR: 0.00988
# TRAIN: Loss: 0.79 Acc: 72.47%
# TEST:  Loss: 0.56 Acc: 80.43%
#
# Epoch: 9/100      LR: 0.00984
# TRAIN: Loss: 0.76 Acc: 73.44%
# TEST:  Loss: 0.55 Acc: 80.80%
#
# Epoch: 10/100     LR: 0.00980
# TRAIN: Loss: 0.72 Acc: 75.00%
# TEST:  Loss: 0.56 Acc: 80.80%
#
# Epoch: 11/100     LR: 0.00976
# TRAIN: Loss: 0.70 Acc: 75.73%
# TEST:  Loss: 0.61 Acc: 79.51%
#
# Epoch: 12/100     LR: 0.00970
# TRAIN: Loss: 0.67 Acc: 76.55%
# TEST:  Loss: 0.52 Acc: 81.97%
#
# Epoch: 13/100     LR: 0.00965
# TRAIN: Loss: 0.66 Acc: 77.01%
# TEST:  Loss: 0.47 Acc: 83.73%
#
# Epoch: 14/100     LR: 0.00959
# TRAIN: Loss: 0.64 Acc: 77.93%
# TEST:  Loss: 0.48 Acc: 83.65%
#
# Epoch: 15/100     LR: 0.00952
# TRAIN: Loss: 0.61 Acc: 78.68%
# TEST:  Loss: 0.50 Acc: 83.32%
#
# Epoch: 16/100     LR: 0.00946
# TRAIN: Loss: 0.61 Acc: 79.04%
# TEST:  Loss: 0.50 Acc: 82.94%
#
# Epoch: 17/100     LR: 0.00938
# TRAIN: Loss: 0.59 Acc: 79.47%
# TEST:  Loss: 0.43 Acc: 85.19%
#
# Epoch: 18/100     LR: 0.00930
# TRAIN: Loss: 0.58 Acc: 79.91%
# TEST:  Loss: 0.40 Acc: 86.23%
#
# Epoch: 19/100     LR: 0.00922
# TRAIN: Loss: 0.56 Acc: 80.80%
# TEST:  Loss: 0.41 Acc: 86.14%
#
# Epoch: 20/100     LR: 0.00914
# TRAIN: Loss: 0.56 Acc: 80.56%
# TEST:  Loss: 0.44 Acc: 84.58%
#
# Epoch: 21/100     LR: 0.00905
# TRAIN: Loss: 0.55 Acc: 81.12%
# TEST:  Loss: 0.38 Acc: 87.18%
#
# Epoch: 22/100     LR: 0.00895
# TRAIN: Loss: 0.53 Acc: 81.50%
# TEST:  Loss: 0.41 Acc: 86.32%
#
# Epoch: 23/100     LR: 0.00885
# TRAIN: Loss: 0.51 Acc: 82.19%
# TEST:  Loss: 0.38 Acc: 87.10%
#
# Epoch: 24/100     LR: 0.00875
# TRAIN: Loss: 0.51 Acc: 82.18%
# TEST:  Loss: 0.38 Acc: 86.96%
#
# Epoch: 25/100     LR: 0.00864
# TRAIN: Loss: 0.50 Acc: 82.45%
# TEST:  Loss: 0.41 Acc: 86.24%
#
# Epoch: 26/100     LR: 0.00854
# TRAIN: Loss: 0.50 Acc: 82.75%
# TEST:  Loss: 0.38 Acc: 87.35%
#
# Epoch: 27/100     LR: 0.00842
# TRAIN: Loss: 0.49 Acc: 83.05%
# TEST:  Loss: 0.37 Acc: 87.62%
#
# Epoch: 28/100     LR: 0.00831
# TRAIN: Loss: 0.47 Acc: 83.50%
# TEST:  Loss: 0.36 Acc: 87.52%
#
# Epoch: 29/100     LR: 0.00819
# TRAIN: Loss: 0.47 Acc: 83.57%
# TEST:  Loss: 0.37 Acc: 87.43%
#
# Epoch: 30/100     LR: 0.00806
# TRAIN: Loss: 0.46 Acc: 83.97%
# TEST:  Loss: 0.34 Acc: 88.10%
#
# Epoch: 31/100     LR: 0.00794
# TRAIN: Loss: 0.45 Acc: 84.26%
# TEST:  Loss: 0.34 Acc: 88.76%
#
# Epoch: 32/100     LR: 0.00781
# TRAIN: Loss: 0.45 Acc: 84.61%
# TEST:  Loss: 0.35 Acc: 87.89%
#
# Epoch: 33/100     LR: 0.00768
# TRAIN: Loss: 0.44 Acc: 84.79%
# TEST:  Loss: 0.36 Acc: 88.14%
#
# Epoch: 34/100     LR: 0.00755
# TRAIN: Loss: 0.44 Acc: 84.85%
# TEST:  Loss: 0.35 Acc: 88.09%
#
# Epoch: 35/100     LR: 0.00741
# TRAIN: Loss: 0.43 Acc: 84.99%
# TEST:  Loss: 0.30 Acc: 89.87%
#
# Epoch: 36/100     LR: 0.00727
# TRAIN: Loss: 0.42 Acc: 85.21%
# TEST:  Loss: 0.29 Acc: 89.89%
#
# Epoch: 37/100     LR: 0.00713
# TRAIN: Loss: 0.41 Acc: 85.48%
# TEST:  Loss: 0.33 Acc: 88.70%
#
# Epoch: 38/100     LR: 0.00699
# TRAIN: Loss: 0.41 Acc: 85.69%
# TEST:  Loss: 0.30 Acc: 89.94%
#
# Epoch: 39/100     LR: 0.00684
# TRAIN: Loss: 0.41 Acc: 85.70%
# TEST:  Loss: 0.27 Acc: 90.37%
#
# Epoch: 40/100     LR: 0.00669
# TRAIN: Loss: 0.40 Acc: 86.21%
# TEST:  Loss: 0.28 Acc: 90.44%
#
# Epoch: 41/100     LR: 0.00655
# TRAIN: Loss: 0.39 Acc: 86.49%
# TEST:  Loss: 0.29 Acc: 90.39%
#
# Epoch: 42/100     LR: 0.00639
# TRAIN: Loss: 0.39 Acc: 86.54%
# TEST:  Loss: 0.27 Acc: 90.56%
#
# Epoch: 43/100     LR: 0.00624
# TRAIN: Loss: 0.38 Acc: 86.69%
# TEST:  Loss: 0.26 Acc: 91.09%
#
# Epoch: 44/100     LR: 0.00609
# TRAIN: Loss: 0.37 Acc: 86.96%
# TEST:  Loss: 0.28 Acc: 90.40%
#
# Epoch: 45/100     LR: 0.00594
# TRAIN: Loss: 0.37 Acc: 87.01%
# TEST:  Loss: 0.28 Acc: 90.44%
#
# Epoch: 46/100     LR: 0.00578
# TRAIN: Loss: 0.36 Acc: 87.51%
# TEST:  Loss: 0.28 Acc: 90.40%
#
# Epoch: 47/100     LR: 0.00563
# TRAIN: Loss: 0.36 Acc: 87.42%
# TEST:  Loss: 0.27 Acc: 90.73%
#
# Epoch: 48/100     LR: 0.00547
# TRAIN: Loss: 0.35 Acc: 87.61%
# TEST:  Loss: 0.28 Acc: 90.62%
#
# Epoch: 49/100     LR: 0.00531
# TRAIN: Loss: 0.35 Acc: 87.76%
# TEST:  Loss: 0.27 Acc: 90.73%
#
# Epoch: 50/100     LR: 0.00516
# TRAIN: Loss: 0.34 Acc: 88.04%
# TEST:  Loss: 0.27 Acc: 91.02%
#
# Epoch: 51/100     LR: 0.00500
# TRAIN: Loss: 0.34 Acc: 88.27%
# TEST:  Loss: 0.31 Acc: 89.87%
#
# Epoch: 52/100     LR: 0.00484
# TRAIN: Loss: 0.34 Acc: 88.20%
# TEST:  Loss: 0.25 Acc: 91.44%
#
# Epoch: 53/100     LR: 0.00469
# TRAIN: Loss: 0.33 Acc: 88.61%
# TEST:  Loss: 0.27 Acc: 90.69%
#
# Epoch: 54/100     LR: 0.00453
# TRAIN: Loss: 0.32 Acc: 88.69%
# TEST:  Loss: 0.25 Acc: 91.58%
#
# Epoch: 55/100     LR: 0.00437
# TRAIN: Loss: 0.32 Acc: 89.06%
# TEST:  Loss: 0.27 Acc: 91.01%
#
# Epoch: 56/100     LR: 0.00422
# TRAIN: Loss: 0.31 Acc: 89.12%
# TEST:  Loss: 0.25 Acc: 91.42%
#
# Epoch: 57/100     LR: 0.00406
# TRAIN: Loss: 0.31 Acc: 89.41%
# TEST:  Loss: 0.24 Acc: 91.70%
#
# Epoch: 58/100     LR: 0.00391
# TRAIN: Loss: 0.30 Acc: 89.43%
# TEST:  Loss: 0.25 Acc: 91.69%
#
# Epoch: 59/100     LR: 0.00376
# TRAIN: Loss: 0.30 Acc: 89.48%
# TEST:  Loss: 0.24 Acc: 91.67%
#
# Epoch: 60/100     LR: 0.00361
# TRAIN: Loss: 0.29 Acc: 89.78%
# TEST:  Loss: 0.22 Acc: 92.34%
#
# Epoch: 61/100     LR: 0.00345
# TRAIN: Loss: 0.29 Acc: 89.95%
# TEST:  Loss: 0.23 Acc: 92.03%
#
# Epoch: 62/100     LR: 0.00331
# TRAIN: Loss: 0.28 Acc: 90.22%
# TEST:  Loss: 0.22 Acc: 92.62%
#
# Epoch: 63/100     LR: 0.00316
# TRAIN: Loss: 0.28 Acc: 90.54%
# TEST:  Loss: 0.23 Acc: 92.23%
#
# Epoch: 64/100     LR: 0.00301
# TRAIN: Loss: 0.27 Acc: 90.43%
# TEST:  Loss: 0.22 Acc: 92.66%
#
# Epoch: 65/100     LR: 0.00287
# TRAIN: Loss: 0.26 Acc: 90.75%
# TEST:  Loss: 0.22 Acc: 92.34%
#
# Epoch: 66/100     LR: 0.00273
# TRAIN: Loss: 0.26 Acc: 90.89%
# TEST:  Loss: 0.23 Acc: 92.27%
#
# Epoch: 67/100     LR: 0.00259
# TRAIN: Loss: 0.25 Acc: 91.07%
# TEST:  Loss: 0.21 Acc: 92.85%
#
# Epoch: 68/100     LR: 0.00245
# TRAIN: Loss: 0.25 Acc: 91.24%
# TEST:  Loss: 0.22 Acc: 92.65%
#
# Epoch: 69/100     LR: 0.00232
# TRAIN: Loss: 0.25 Acc: 91.40%
# TEST:  Loss: 0.21 Acc: 92.99%
#
# Epoch: 70/100     LR: 0.00219
# TRAIN: Loss: 0.24 Acc: 91.55%
# TEST:  Loss: 0.21 Acc: 93.08%
#
# Epoch: 71/100     LR: 0.00206
# TRAIN: Loss: 0.24 Acc: 91.66%
# TEST:  Loss: 0.21 Acc: 92.87%
#
# Epoch: 72/100     LR: 0.00194
# TRAIN: Loss: 0.23 Acc: 91.83%
# TEST:  Loss: 0.21 Acc: 93.21%
#
# Epoch: 73/100     LR: 0.00181
# TRAIN: Loss: 0.23 Acc: 91.92%
# TEST:  Loss: 0.21 Acc: 93.00%
#
# Epoch: 74/100     LR: 0.00169
# TRAIN: Loss: 0.24 Acc: 91.82%
# TEST:  Loss: 0.22 Acc: 92.82%
#
# Epoch: 75/100     LR: 0.00158
# TRAIN: Loss: 0.22 Acc: 92.31%
# TEST:  Loss: 0.20 Acc: 93.24%
#
# Epoch: 76/100     LR: 0.00146
# TRAIN: Loss: 0.21 Acc: 92.55%
# TEST:  Loss: 0.21 Acc: 93.06%
#
# Epoch: 77/100     LR: 0.00136
# TRAIN: Loss: 0.21 Acc: 92.66%
# TEST:  Loss: 0.20 Acc: 93.40%
#
# Epoch: 78/100     LR: 0.00125
# TRAIN: Loss: 0.21 Acc: 92.88%
# TEST:  Loss: 0.20 Acc: 93.44%
#
# Epoch: 79/100     LR: 0.00115
# TRAIN: Loss: 0.20 Acc: 92.97%
# TEST:  Loss: 0.20 Acc: 93.36%
#
# Epoch: 80/100     LR: 0.00105
# TRAIN: Loss: 0.20 Acc: 92.89%
# TEST:  Loss: 0.19 Acc: 93.51%
#
# Epoch: 81/100     LR: 0.00095
# TRAIN: Loss: 0.20 Acc: 93.11%
# TEST:  Loss: 0.20 Acc: 93.48%
#
# Epoch: 82/100     LR: 0.00086
# TRAIN: Loss: 0.19 Acc: 93.39%
# TEST:  Loss: 0.19 Acc: 93.54%
#
# Epoch: 83/100     LR: 0.00078
# TRAIN: Loss: 0.19 Acc: 93.30%
# TEST:  Loss: 0.20 Acc: 93.44%
#
# Epoch: 84/100     LR: 0.00070
# TRAIN: Loss: 0.19 Acc: 93.42%
# TEST:  Loss: 0.20 Acc: 93.57%
#
# Epoch: 85/100     LR: 0.00062
# TRAIN: Loss: 0.19 Acc: 93.36%
# TEST:  Loss: 0.19 Acc: 93.66%
#
# Epoch: 86/100     LR: 0.00054
# TRAIN: Loss: 0.18 Acc: 93.67%
# TEST:  Loss: 0.19 Acc: 93.78%
#
# Epoch: 87/100     LR: 0.00048
# TRAIN: Loss: 0.18 Acc: 93.75%
# TEST:  Loss: 0.19 Acc: 93.76%
#
# Epoch: 88/100     LR: 0.00041
# TRAIN: Loss: 0.18 Acc: 93.75%
# TEST:  Loss: 0.19 Acc: 93.86%
#
# Epoch: 89/100     LR: 0.00035
# TRAIN: Loss: 0.18 Acc: 93.85%
# TEST:  Loss: 0.19 Acc: 93.91%
#
# Epoch: 90/100     LR: 0.00030
# TRAIN: Loss: 0.18 Acc: 93.97%
# TEST:  Loss: 0.19 Acc: 93.94%
#
# Epoch: 91/100     LR: 0.00024
# TRAIN: Loss: 0.17 Acc: 94.18%
# TEST:  Loss: 0.19 Acc: 93.98%
#
# Epoch: 92/100     LR: 0.00020
# TRAIN: Loss: 0.17 Acc: 94.07%
# TEST:  Loss: 0.19 Acc: 93.84%
#
# Epoch: 93/100     LR: 0.00016
# TRAIN: Loss: 0.17 Acc: 94.19%
# TEST:  Loss: 0.19 Acc: 93.87%
#
# Epoch: 94/100     LR: 0.00012
# TRAIN: Loss: 0.17 Acc: 94.06%
# TEST:  Loss: 0.19 Acc: 93.84%
#
# Epoch: 95/100     LR: 0.00009
# TRAIN: Loss: 0.17 Acc: 94.14%
# TEST:  Loss: 0.19 Acc: 93.98%
#
# Epoch: 96/100     LR: 0.00006
# TRAIN: Loss: 0.17 Acc: 94.32%
# TEST:  Loss: 0.19 Acc: 94.02%
#
# Epoch: 97/100     LR: 0.00004
# TRAIN: Loss: 0.16 Acc: 94.39%
# TEST:  Loss: 0.18 Acc: 93.99%
#
# Epoch: 98/100     LR: 0.00002
# TRAIN: Loss: 0.16 Acc: 94.44%
# TEST:  Loss: 0.19 Acc: 94.00%
#
# Epoch: 99/100     LR: 0.00001
# TRAIN: Loss: 0.17 Acc: 94.40%
# TEST:  Loss: 0.19 Acc: 93.98%
#
# Epoch: 100/100    LR: 0.00000
# TRAIN: Loss: 0.17 Acc: 94.38%
# TEST:  Loss: 0.19 Acc: 94.04%
# Model saved as ResNetCustom_epoch100_acc94.pth
# Training complete

# %%
# Run inference
try:
    inference('ResNetCustom_epoch100_acc94.pth')
except FileNotFoundError as e:
    print(f'Inference failed: {e}')
# Out:
# Loading data...
# Loading model...
# Running inference...
# Predictions saved as ResNetCustom_epoch100_acc94.csv
