# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/deep-learning-spring-2025-project-1/cifar_test_nolabel.pkl
# /kaggle/input/deep-learning-spring-2025-project-1/cifar-10-python/cifar-10-batches-py/data_batch_1
# /kaggle/input/deep-learning-spring-2025-project-1/cifar-10-python/cifar-10-batches-py/data_batch_2
# /kaggle/input/deep-learning-spring-2025-project-1/cifar-10-python/cifar-10-batches-py/batches.meta
# /kaggle/input/deep-learning-spring-2025-project-1/cifar-10-python/cifar-10-batches-py/test_batch
# /kaggle/input/deep-learning-spring-2025-project-1/cifar-10-python/cifar-10-batches-py/data_batch_3
# /kaggle/input/deep-learning-spring-2025-project-1/cifar-10-python/cifar-10-batches-py/data_batch_5
# /kaggle/input/deep-learning-spring-2025-project-1/cifar-10-python/cifar-10-batches-py/data_batch_4
# /kaggle/input/deep-learning-spring-2025-project-1/cifar-10-python/cifar-10-batches-py/readme.html

# %%
# !git clone https://github.com/timothycao/cifar10_classifier.git
# %cd cifar10_classifier
# Out:
# Cloning into 'cifar10_classifier'...
# remote: Enumerating objects: 84, done.
# remote: Counting objects: 100% (84/84), done.
# remote: Compressing objects: 100% (57/57), done.
# remote: Total 84 (delta 46), reused 62 (delta 24), pack-reused 0 (from 0)
# Receiving objects: 100% (84/84), 21.73 KiB | 3.62 MiB/s, done.
# Resolving deltas: 100% (46/46), done.
# /kaggle/working/cifar10_classifier

# %%
import torch.optim as optim
import torchvision.transforms as transforms
from model import create_model
from train import main as train
from inference import main as inference


# Model parameters
MODEL_NAME = 'ResNetCustom'
BLOCK_TYPE = 'basic'
NUM_BLOCKS_PER_LAYER = [2, 2, 2, 2]
NUM_CHANNELS_PER_LAYER = [42, 84, 168, 336]
KERNEL_SIZE_PER_LAYER = [3, 3, 3, 3]
SKIP_KERNEL_SIZE_PER_LAYER = [1, 1, 1, 1]
EXPANSION = 1
POOL_SIZE = 1


# Training parameters
EPOCHS = 200
TRAIN_BATCH_SIZE = 128
TEST_BATCH_SIZE = 100
AUGMENTATIONS = [
    transforms.RandomHorizontalFlip(p=0.5),
    transforms.RandomCrop(32, padding=4),
    transforms.ColorJitter(brightness=0.2, contrast=0.2, saturation=0.2, hue=0.1),
    transforms.RandomAffine(degrees=10, translate=(0.1, 0.1), scale=(0.8, 1.2)),
    transforms.RandAugment(num_ops=2, magnitude=12),
    transforms.GaussianBlur(kernel_size=3, sigma=(0.1, 2.0)),
    transforms.RandomGrayscale(p=0.2)
]
SAVE_MODE = 'best'  # Options: 'best', 'every'
SAVE_EVERY_N = 1

# Initialize model
try:
    model = create_model(
        name=MODEL_NAME,
        block_type=BLOCK_TYPE,
        blocks_per_layer=NUM_BLOCKS_PER_LAYER,
        channels_per_layer=NUM_CHANNELS_PER_LAYER,
        kernels_per_layer=KERNEL_SIZE_PER_LAYER,
        skip_kernels_per_layer=SKIP_KERNEL_SIZE_PER_LAYER,
        expansion=EXPANSION,
        pool_size=POOL_SIZE
    )
    print('Total model parameters:', sum(p.numel() for p in model.parameters() if p.requires_grad))
except AssertionError as e:
    print(f'Failed to create model: {e}')
    exit(1)
# Out:
# Total model parameters: 4815940

# %%
# Train model
try:
    # Define optimizer
    OPTIMIZER = optim.SGD(model.parameters(), lr=0.01, momentum=0.9, weight_decay=8e-4)
    
    # Define scheduler
    SCHEDULER = optim.lr_scheduler.CosineAnnealingLR(OPTIMIZER, T_max=EPOCHS)
    
    # If no scheduler, set to None
    SCHEDULER = SCHEDULER if 'SCHEDULER' in locals() and SCHEDULER is not None else None

    # train(model, EPOCHS)
    train(model, EPOCHS, train_batch_size=TRAIN_BATCH_SIZE, test_batch_size=TEST_BATCH_SIZE, augmentations=AUGMENTATIONS,
          optimizer=OPTIMIZER, scheduler=SCHEDULER, save=SAVE_MODE, every_n=SAVE_EVERY_N)
except (ValueError, TypeError) as e:
    print(f'Training failed: {e}')
    exit(1)
# Out:
# Total model parameters: 4815940
# Loading data...
# Preprocessing pipeline:
#  Compose(
#     RandomHorizontalFlip(p=0.5)
#     RandomCrop(size=(32, 32), padding=4)
#     ColorJitter(brightness=(0.8, 1.2), contrast=(0.8, 1.2), saturation=(0.8, 1.2), hue=(-0.1, 0.1))
#     RandomAffine(degrees=[-10.0, 10.0], translate=(0.1, 0.1), scale=(0.8, 1.2))
#     RandAugment(num_ops=2, magnitude=12, num_magnitude_bins=31, interpolation=InterpolationMode.NEAREST, fill=None)
#     GaussianBlur(kernel_size=(3, 3), sigma=(0.1, 2.0))
#     RandomGrayscale(p=0.2)
#     ToTensor()
#     Normalize(mean=(0.4914, 0.4822, 0.4465), std=(0.2023, 0.1994, 0.201))
# )
# Files already downloaded and verified
# Files already downloaded and verified
# Initializing model...
# Training model...
#
# Epoch: 1/200      LR: 0.01000
# TRAIN: Loss: 1.91 Acc: 29.57%
# TEST:  Loss: 1.61 Acc: 42.60%
#
# Epoch: 2/200      LR: 0.01000
# TRAIN: Loss: 1.53 Acc: 45.10%
# TEST:  Loss: 1.16 Acc: 58.44%
#
# Epoch: 3/200      LR: 0.01000
# TRAIN: Loss: 1.33 Acc: 52.95%
# TEST:  Loss: 1.06 Acc: 62.47%
#
# Epoch: 4/200      LR: 0.00999
# TRAIN: Loss: 1.21 Acc: 57.51%
# TEST:  Loss: 1.11 Acc: 62.22%
#
# Epoch: 5/200      LR: 0.00999
# TRAIN: Loss: 1.13 Acc: 60.17%
# TEST:  Loss: 0.91 Acc: 68.59%
#
# Epoch: 6/200      LR: 0.00998
# TRAIN: Loss: 1.08 Acc: 61.97%
# TEST:  Loss: 0.87 Acc: 69.75%
#
# Epoch: 7/200      LR: 0.00998
# TRAIN: Loss: 1.03 Acc: 63.64%
# TEST:  Loss: 0.82 Acc: 71.92%
#
# Epoch: 8/200      LR: 0.00997
# TRAIN: Loss: 0.99 Acc: 65.70%
# TEST:  Loss: 0.90 Acc: 69.51%
#
# Epoch: 9/200      LR: 0.00996
# TRAIN: Loss: 0.96 Acc: 66.56%
# TEST:  Loss: 0.66 Acc: 77.47%
#
# Epoch: 10/200     LR: 0.00995
# TRAIN: Loss: 0.93 Acc: 67.42%
# TEST:  Loss: 0.67 Acc: 77.12%
#
# Epoch: 11/200     LR: 0.00994
# TRAIN: Loss: 0.91 Acc: 68.63%
# TEST:  Loss: 0.60 Acc: 79.81%
#
# Epoch: 12/200     LR: 0.00993
# TRAIN: Loss: 0.89 Acc: 69.02%
# TEST:  Loss: 0.58 Acc: 80.18%
#
# Epoch: 13/200     LR: 0.00991
# TRAIN: Loss: 0.86 Acc: 69.89%
# TEST:  Loss: 0.64 Acc: 78.43%
#
# Epoch: 14/200     LR: 0.00990
# TRAIN: Loss: 0.85 Acc: 70.55%
# TEST:  Loss: 0.56 Acc: 80.81%
#
# Epoch: 15/200     LR: 0.00988
# TRAIN: Loss: 0.83 Acc: 71.15%
# TEST:  Loss: 0.55 Acc: 80.69%
#
# Epoch: 16/200     LR: 0.00986
# TRAIN: Loss: 0.81 Acc: 71.57%
# TEST:  Loss: 0.59 Acc: 79.95%
#
# Epoch: 17/200     LR: 0.00984
# TRAIN: Loss: 0.80 Acc: 72.21%
# TEST:  Loss: 0.56 Acc: 81.33%
#
# Epoch: 18/200     LR: 0.00982
# TRAIN: Loss: 0.78 Acc: 72.65%
# TEST:  Loss: 0.52 Acc: 82.13%
#
# Epoch: 19/200     LR: 0.00980
# TRAIN: Loss: 0.78 Acc: 72.76%
# TEST:  Loss: 0.50 Acc: 83.04%
#
# Epoch: 20/200     LR: 0.00978
# TRAIN: Loss: 0.76 Acc: 73.73%
# TEST:  Loss: 0.51 Acc: 82.21%
#
# Epoch: 21/200     LR: 0.00976
# TRAIN: Loss: 0.76 Acc: 73.95%
# TEST:  Loss: 0.49 Acc: 83.13%
#
# Epoch: 22/200     LR: 0.00973
# TRAIN: Loss: 0.74 Acc: 74.16%
# TEST:  Loss: 0.61 Acc: 79.69%
#
# Epoch: 23/200     LR: 0.00970
# TRAIN: Loss: 0.74 Acc: 74.64%
# TEST:  Loss: 0.46 Acc: 84.31%
#
# Epoch: 24/200     LR: 0.00968
# TRAIN: Loss: 0.73 Acc: 74.77%
# TEST:  Loss: 0.44 Acc: 84.57%
#
# Epoch: 25/200     LR: 0.00965
# TRAIN: Loss: 0.72 Acc: 75.10%
# TEST:  Loss: 0.49 Acc: 83.28%
#
# Epoch: 26/200     LR: 0.00962
# TRAIN: Loss: 0.71 Acc: 75.37%
# TEST:  Loss: 0.51 Acc: 82.67%
#
# Epoch: 27/200     LR: 0.00959
# TRAIN: Loss: 0.71 Acc: 75.45%
# TEST:  Loss: 0.51 Acc: 82.84%
#
# Epoch: 28/200     LR: 0.00956
# TRAIN: Loss: 0.69 Acc: 76.05%
# TEST:  Loss: 0.44 Acc: 84.39%
#
# Epoch: 29/200     LR: 0.00952
# TRAIN: Loss: 0.69 Acc: 76.15%
# TEST:  Loss: 0.44 Acc: 84.78%
#
# Epoch: 30/200     LR: 0.00949
# TRAIN: Loss: 0.68 Acc: 76.30%
# TEST:  Loss: 0.51 Acc: 82.79%
#
# Epoch: 31/200     LR: 0.00946
# TRAIN: Loss: 0.68 Acc: 76.65%
# TEST:  Loss: 0.42 Acc: 85.44%
#
# Epoch: 32/200     LR: 0.00942
# TRAIN: Loss: 0.67 Acc: 76.61%
# TEST:  Loss: 0.40 Acc: 86.08%
#
# Epoch: 33/200     LR: 0.00938
# TRAIN: Loss: 0.67 Acc: 76.86%
# TEST:  Loss: 0.45 Acc: 85.09%
#
# Epoch: 34/200     LR: 0.00934
# TRAIN: Loss: 0.65 Acc: 77.32%
# TEST:  Loss: 0.41 Acc: 85.91%
#
# Epoch: 35/200     LR: 0.00930
# TRAIN: Loss: 0.65 Acc: 77.46%
# TEST:  Loss: 0.39 Acc: 86.87%
#
# Epoch: 36/200     LR: 0.00926
# TRAIN: Loss: 0.65 Acc: 77.53%
# TEST:  Loss: 0.38 Acc: 86.74%
#
# Epoch: 37/200     LR: 0.00922
# TRAIN: Loss: 0.65 Acc: 77.64%
# TEST:  Loss: 0.38 Acc: 87.07%
#
# Epoch: 38/200     LR: 0.00918
# TRAIN: Loss: 0.64 Acc: 77.89%
# TEST:  Loss: 0.44 Acc: 85.07%
#
# Epoch: 39/200     LR: 0.00914
# TRAIN: Loss: 0.63 Acc: 78.12%
# TEST:  Loss: 0.40 Acc: 86.12%
#
# Epoch: 40/200     LR: 0.00909
# TRAIN: Loss: 0.63 Acc: 78.12%
# TEST:  Loss: 0.41 Acc: 85.82%
#
# Epoch: 41/200     LR: 0.00905
# TRAIN: Loss: 0.63 Acc: 78.17%
# TEST:  Loss: 0.36 Acc: 87.34%
#
# Epoch: 42/200     LR: 0.00900
# TRAIN: Loss: 0.63 Acc: 78.56%
# TEST:  Loss: 0.41 Acc: 86.00%
#
# Epoch: 43/200     LR: 0.00895
# TRAIN: Loss: 0.63 Acc: 78.31%
# TEST:  Loss: 0.37 Acc: 87.58%
#
# Epoch: 44/200     LR: 0.00890
# TRAIN: Loss: 0.61 Acc: 78.81%
# TEST:  Loss: 0.37 Acc: 87.47%
#
# Epoch: 45/200     LR: 0.00885
# TRAIN: Loss: 0.61 Acc: 78.87%
# TEST:  Loss: 0.43 Acc: 85.27%
#
# Epoch: 46/200     LR: 0.00880
# TRAIN: Loss: 0.61 Acc: 79.18%
# TEST:  Loss: 0.40 Acc: 85.86%
#
# Epoch: 47/200     LR: 0.00875
# TRAIN: Loss: 0.61 Acc: 78.89%
# TEST:  Loss: 0.36 Acc: 87.96%
#
# Epoch: 48/200     LR: 0.00870
# TRAIN: Loss: 0.61 Acc: 78.89%
# TEST:  Loss: 0.37 Acc: 87.20%
#
# Epoch: 49/200     LR: 0.00864
# TRAIN: Loss: 0.60 Acc: 79.56%
# TEST:  Loss: 0.40 Acc: 86.14%
#
# Epoch: 50/200     LR: 0.00859
# TRAIN: Loss: 0.60 Acc: 79.43%
# TEST:  Loss: 0.36 Acc: 87.35%
#
# Epoch: 51/200     LR: 0.00854
# TRAIN: Loss: 0.60 Acc: 79.09%
# TEST:  Loss: 0.35 Acc: 87.66%
#
# Epoch: 52/200     LR: 0.00848
# TRAIN: Loss: 0.59 Acc: 79.66%
# TEST:  Loss: 0.36 Acc: 87.82%
#
# Epoch: 53/200     LR: 0.00842
# TRAIN: Loss: 0.59 Acc: 79.82%
# TEST:  Loss: 0.35 Acc: 88.27%
#
# Epoch: 54/200     LR: 0.00837
# TRAIN: Loss: 0.59 Acc: 79.76%
# TEST:  Loss: 0.40 Acc: 86.75%
#
# Epoch: 55/200     LR: 0.00831
# TRAIN: Loss: 0.58 Acc: 80.14%
# TEST:  Loss: 0.36 Acc: 87.78%
#
# Epoch: 56/200     LR: 0.00825
# TRAIN: Loss: 0.58 Acc: 80.05%
# TEST:  Loss: 0.34 Acc: 88.52%
#
# Epoch: 57/200     LR: 0.00819
# TRAIN: Loss: 0.58 Acc: 80.04%
# TEST:  Loss: 0.35 Acc: 88.37%
#
# Epoch: 58/200     LR: 0.00813
# TRAIN: Loss: 0.57 Acc: 80.16%
# TEST:  Loss: 0.35 Acc: 88.35%
#
# Epoch: 59/200     LR: 0.00806
# TRAIN: Loss: 0.57 Acc: 80.23%
# TEST:  Loss: 0.35 Acc: 88.26%
#
# Epoch: 60/200     LR: 0.00800
# TRAIN: Loss: 0.57 Acc: 80.43%
# TEST:  Loss: 0.34 Acc: 88.15%
#
# Epoch: 61/200     LR: 0.00794
# TRAIN: Loss: 0.58 Acc: 80.01%
# TEST:  Loss: 0.34 Acc: 88.20%
#
# Epoch: 62/200     LR: 0.00788
# TRAIN: Loss: 0.57 Acc: 80.55%
# TEST:  Loss: 0.34 Acc: 88.64%
#
# Epoch: 63/200     LR: 0.00781
# TRAIN: Loss: 0.57 Acc: 80.47%
# TEST:  Loss: 0.36 Acc: 87.41%
#
# Epoch: 64/200     LR: 0.00775
# TRAIN: Loss: 0.56 Acc: 80.61%
# TEST:  Loss: 0.35 Acc: 87.68%
#
# Epoch: 65/200     LR: 0.00768
# TRAIN: Loss: 0.55 Acc: 80.78%
# TEST:  Loss: 0.32 Acc: 88.88%
#
# Epoch: 66/200     LR: 0.00761
# TRAIN: Loss: 0.55 Acc: 81.05%
# TEST:  Loss: 0.35 Acc: 87.92%
#
# Epoch: 67/200     LR: 0.00755
# TRAIN: Loss: 0.55 Acc: 80.89%
# TEST:  Loss: 0.31 Acc: 89.19%
#
# Epoch: 68/200     LR: 0.00748
# TRAIN: Loss: 0.55 Acc: 80.97%
# TEST:  Loss: 0.36 Acc: 87.93%
#
# Epoch: 69/200     LR: 0.00741
# TRAIN: Loss: 0.54 Acc: 81.20%
# TEST:  Loss: 0.32 Acc: 89.33%
#
# Epoch: 70/200     LR: 0.00734
# TRAIN: Loss: 0.55 Acc: 81.14%
# TEST:  Loss: 0.32 Acc: 88.74%
#
# Epoch: 71/200     LR: 0.00727
# TRAIN: Loss: 0.54 Acc: 81.29%
# TEST:  Loss: 0.35 Acc: 88.02%
#
# Epoch: 72/200     LR: 0.00720
# TRAIN: Loss: 0.54 Acc: 81.45%
# TEST:  Loss: 0.32 Acc: 89.18%
#
# Epoch: 73/200     LR: 0.00713
# TRAIN: Loss: 0.54 Acc: 81.54%
# TEST:  Loss: 0.35 Acc: 88.30%
#
# Epoch: 74/200     LR: 0.00706
# TRAIN: Loss: 0.53 Acc: 81.50%
# TEST:  Loss: 0.32 Acc: 89.06%
#
# Epoch: 75/200     LR: 0.00699
# TRAIN: Loss: 0.53 Acc: 81.59%
# TEST:  Loss: 0.33 Acc: 88.38%
#
# Epoch: 76/200     LR: 0.00691
# TRAIN: Loss: 0.53 Acc: 81.97%
# TEST:  Loss: 0.31 Acc: 89.10%
#
# Epoch: 77/200     LR: 0.00684
# TRAIN: Loss: 0.52 Acc: 81.98%
# TEST:  Loss: 0.35 Acc: 88.23%
#
# Epoch: 78/200     LR: 0.00677
# TRAIN: Loss: 0.53 Acc: 81.81%
# TEST:  Loss: 0.30 Acc: 89.86%
#
# Epoch: 79/200     LR: 0.00669
# TRAIN: Loss: 0.53 Acc: 81.82%
# TEST:  Loss: 0.35 Acc: 88.23%
#
# Epoch: 80/200     LR: 0.00662
# TRAIN: Loss: 0.52 Acc: 82.20%
# TEST:  Loss: 0.30 Acc: 89.90%
#
# Epoch: 81/200     LR: 0.00655
# TRAIN: Loss: 0.52 Acc: 82.22%
# TEST:  Loss: 0.32 Acc: 89.07%
#
# Epoch: 82/200     LR: 0.00647
# TRAIN: Loss: 0.51 Acc: 82.46%
# TEST:  Loss: 0.30 Acc: 89.57%
#
# Epoch: 83/200     LR: 0.00639
# TRAIN: Loss: 0.51 Acc: 82.39%
# TEST:  Loss: 0.29 Acc: 90.21%
#
# Epoch: 84/200     LR: 0.00632
# TRAIN: Loss: 0.51 Acc: 82.53%
# TEST:  Loss: 0.31 Acc: 89.37%
#
# Epoch: 85/200     LR: 0.00624
# TRAIN: Loss: 0.51 Acc: 82.59%
# TEST:  Loss: 0.30 Acc: 89.85%
#
# Epoch: 86/200     LR: 0.00617
# TRAIN: Loss: 0.51 Acc: 82.46%
# TEST:  Loss: 0.32 Acc: 88.80%
#
# Epoch: 87/200     LR: 0.00609
# TRAIN: Loss: 0.50 Acc: 83.04%
# TEST:  Loss: 0.35 Acc: 87.89%
#
# Epoch: 88/200     LR: 0.00601
# TRAIN: Loss: 0.50 Acc: 82.96%
# TEST:  Loss: 0.30 Acc: 89.75%
#
# Epoch: 89/200     LR: 0.00594
# TRAIN: Loss: 0.50 Acc: 83.08%
# TEST:  Loss: 0.28 Acc: 90.01%
#
# Epoch: 90/200     LR: 0.00586
# TRAIN: Loss: 0.49 Acc: 82.98%
# TEST:  Loss: 0.30 Acc: 89.52%
#
# Epoch: 91/200     LR: 0.00578
# TRAIN: Loss: 0.49 Acc: 83.07%
# TEST:  Loss: 0.28 Acc: 90.44%
#
# Epoch: 92/200     LR: 0.00570
# TRAIN: Loss: 0.49 Acc: 83.26%
# TEST:  Loss: 0.32 Acc: 89.26%
#
# Epoch: 93/200     LR: 0.00563
# TRAIN: Loss: 0.49 Acc: 83.26%
# TEST:  Loss: 0.31 Acc: 89.53%
#
# Epoch: 94/200     LR: 0.00555
# TRAIN: Loss: 0.48 Acc: 83.45%
# TEST:  Loss: 0.29 Acc: 90.33%
#
# Epoch: 95/200     LR: 0.00547
# TRAIN: Loss: 0.48 Acc: 83.71%
# TEST:  Loss: 0.28 Acc: 90.30%
#
# Epoch: 96/200     LR: 0.00539
# TRAIN: Loss: 0.48 Acc: 83.38%
# TEST:  Loss: 0.27 Acc: 90.67%
#
# Epoch: 97/200     LR: 0.00531
# TRAIN: Loss: 0.47 Acc: 83.74%
# TEST:  Loss: 0.27 Acc: 90.88%
#
# Epoch: 98/200     LR: 0.00524
# TRAIN: Loss: 0.47 Acc: 83.71%
# TEST:  Loss: 0.31 Acc: 89.63%
#
# Epoch: 99/200     LR: 0.00516
# TRAIN: Loss: 0.47 Acc: 83.80%
# TEST:  Loss: 0.28 Acc: 90.73%
#
# Epoch: 100/200    LR: 0.00508
# TRAIN: Loss: 0.47 Acc: 84.05%
# TEST:  Loss: 0.29 Acc: 90.48%
#
# Epoch: 101/200    LR: 0.00500
# TRAIN: Loss: 0.46 Acc: 84.09%
# TEST:  Loss: 0.28 Acc: 90.39%
#
# Epoch: 102/200    LR: 0.00492
# TRAIN: Loss: 0.46 Acc: 84.27%
# TEST:  Loss: 0.26 Acc: 91.30%
#
# Epoch: 103/200    LR: 0.00484
# TRAIN: Loss: 0.47 Acc: 83.83%
# TEST:  Loss: 0.27 Acc: 90.68%
#
# Epoch: 104/200    LR: 0.00476
# TRAIN: Loss: 0.46 Acc: 84.44%
# TEST:  Loss: 0.28 Acc: 90.25%
#
# Epoch: 105/200    LR: 0.00469
# TRAIN: Loss: 0.45 Acc: 84.29%
# TEST:  Loss: 0.28 Acc: 90.53%
#
# Epoch: 106/200    LR: 0.00461
# TRAIN: Loss: 0.45 Acc: 84.38%
# TEST:  Loss: 0.28 Acc: 90.48%
#
# Epoch: 107/200    LR: 0.00453
# TRAIN: Loss: 0.45 Acc: 84.47%
# TEST:  Loss: 0.28 Acc: 90.61%
#
# Epoch: 108/200    LR: 0.00445
# TRAIN: Loss: 0.45 Acc: 84.72%
# TEST:  Loss: 0.27 Acc: 90.90%
#
# Epoch: 109/200    LR: 0.00437
# TRAIN: Loss: 0.45 Acc: 84.80%
# TEST:  Loss: 0.28 Acc: 90.54%
#
# Epoch: 110/200    LR: 0.00430
# TRAIN: Loss: 0.44 Acc: 85.06%
# TEST:  Loss: 0.27 Acc: 91.05%
#
# Epoch: 111/200    LR: 0.00422
# TRAIN: Loss: 0.43 Acc: 84.96%
# TEST:  Loss: 0.24 Acc: 91.84%
#
# Epoch: 112/200    LR: 0.00414
# TRAIN: Loss: 0.43 Acc: 84.94%
# TEST:  Loss: 0.25 Acc: 91.65%
#
# Epoch: 113/200    LR: 0.00406
# TRAIN: Loss: 0.43 Acc: 85.19%
# TEST:  Loss: 0.25 Acc: 91.66%
#
# Epoch: 114/200    LR: 0.00399
# TRAIN: Loss: 0.43 Acc: 85.40%
# TEST:  Loss: 0.27 Acc: 91.15%
#
# Epoch: 115/200    LR: 0.00391
# TRAIN: Loss: 0.42 Acc: 85.58%
# TEST:  Loss: 0.27 Acc: 91.05%
#
# Epoch: 116/200    LR: 0.00383
# TRAIN: Loss: 0.42 Acc: 85.71%
# TEST:  Loss: 0.24 Acc: 92.04%
#
# Epoch: 117/200    LR: 0.00376
# TRAIN: Loss: 0.41 Acc: 86.09%
# TEST:  Loss: 0.26 Acc: 91.17%
#
# Epoch: 118/200    LR: 0.00368
# TRAIN: Loss: 0.41 Acc: 85.71%
# TEST:  Loss: 0.24 Acc: 91.71%
#
# Epoch: 119/200    LR: 0.00361
# TRAIN: Loss: 0.42 Acc: 85.66%
# TEST:  Loss: 0.25 Acc: 91.79%
#
# Epoch: 120/200    LR: 0.00353
# TRAIN: Loss: 0.41 Acc: 85.92%
# TEST:  Loss: 0.24 Acc: 91.70%
#
# Epoch: 121/200    LR: 0.00345
# TRAIN: Loss: 0.42 Acc: 85.62%
# TEST:  Loss: 0.26 Acc: 91.40%
#
# Epoch: 122/200    LR: 0.00338
# TRAIN: Loss: 0.41 Acc: 86.12%
# TEST:  Loss: 0.25 Acc: 91.76%
#
# Epoch: 123/200    LR: 0.00331
# TRAIN: Loss: 0.40 Acc: 86.19%
# TEST:  Loss: 0.26 Acc: 91.56%
#
# Epoch: 124/200    LR: 0.00323
# TRAIN: Loss: 0.40 Acc: 86.36%
# TEST:  Loss: 0.24 Acc: 91.92%
#
# Epoch: 125/200    LR: 0.00316
# TRAIN: Loss: 0.40 Acc: 86.28%
# TEST:  Loss: 0.25 Acc: 91.70%
#
# Epoch: 126/200    LR: 0.00309
# TRAIN: Loss: 0.39 Acc: 86.56%
# TEST:  Loss: 0.24 Acc: 91.84%
#
# Epoch: 127/200    LR: 0.00301
# TRAIN: Loss: 0.39 Acc: 86.69%
# TEST:  Loss: 0.24 Acc: 91.87%
#
# Epoch: 128/200    LR: 0.00294
# TRAIN: Loss: 0.39 Acc: 86.64%
# TEST:  Loss: 0.25 Acc: 91.51%
#
# Epoch: 129/200    LR: 0.00287
# TRAIN: Loss: 0.39 Acc: 86.72%
# TEST:  Loss: 0.23 Acc: 92.18%
#
# Epoch: 130/200    LR: 0.00280
# TRAIN: Loss: 0.38 Acc: 86.91%
# TEST:  Loss: 0.24 Acc: 91.99%
#
# Epoch: 131/200    LR: 0.00273
# TRAIN: Loss: 0.37 Acc: 87.16%
# TEST:  Loss: 0.23 Acc: 91.92%
#
# Epoch: 132/200    LR: 0.00266
# TRAIN: Loss: 0.36 Acc: 87.68%
# TEST:  Loss: 0.24 Acc: 92.25%
#
# Epoch: 133/200    LR: 0.00259
# TRAIN: Loss: 0.37 Acc: 87.06%
# TEST:  Loss: 0.24 Acc: 91.90%
#
# Epoch: 134/200    LR: 0.00252
# TRAIN: Loss: 0.37 Acc: 87.27%
# TEST:  Loss: 0.23 Acc: 92.06%
#
# Epoch: 135/200    LR: 0.00245
# TRAIN: Loss: 0.36 Acc: 87.62%
# TEST:  Loss: 0.23 Acc: 92.24%
#
# Epoch: 136/200    LR: 0.00239
# TRAIN: Loss: 0.36 Acc: 87.62%
# TEST:  Loss: 0.24 Acc: 92.06%
#
# Epoch: 137/200    LR: 0.00232
# TRAIN: Loss: 0.36 Acc: 87.73%
# TEST:  Loss: 0.23 Acc: 92.07%
#
# Epoch: 138/200    LR: 0.00225
# TRAIN: Loss: 0.35 Acc: 87.92%
# TEST:  Loss: 0.24 Acc: 91.98%
#
# Epoch: 139/200    LR: 0.00219
# TRAIN: Loss: 0.35 Acc: 88.00%
# TEST:  Loss: 0.23 Acc: 92.38%
#
# Epoch: 140/200    LR: 0.00212
# TRAIN: Loss: 0.35 Acc: 88.06%
# TEST:  Loss: 0.24 Acc: 92.26%
#
# Epoch: 141/200    LR: 0.00206
# TRAIN: Loss: 0.34 Acc: 88.45%
# TEST:  Loss: 0.23 Acc: 92.69%
#
# Epoch: 142/200    LR: 0.00200
# TRAIN: Loss: 0.34 Acc: 88.21%
# TEST:  Loss: 0.23 Acc: 92.43%
#
# Epoch: 143/200    LR: 0.00194
# TRAIN: Loss: 0.33 Acc: 88.71%
# TEST:  Loss: 0.22 Acc: 92.86%
#
# Epoch: 144/200    LR: 0.00187
# TRAIN: Loss: 0.34 Acc: 88.46%
# TEST:  Loss: 0.23 Acc: 92.56%
#
# Epoch: 145/200    LR: 0.00181
# TRAIN: Loss: 0.33 Acc: 88.91%
# TEST:  Loss: 0.22 Acc: 92.86%
#
# Epoch: 146/200    LR: 0.00175
# TRAIN: Loss: 0.33 Acc: 88.56%
# TEST:  Loss: 0.22 Acc: 92.73%
#
# Epoch: 147/200    LR: 0.00169
# TRAIN: Loss: 0.33 Acc: 88.89%
# TEST:  Loss: 0.22 Acc: 92.66%
#
# Epoch: 148/200    LR: 0.00163
# TRAIN: Loss: 0.32 Acc: 88.91%
# TEST:  Loss: 0.22 Acc: 92.70%
#
# Epoch: 149/200    LR: 0.00158
# TRAIN: Loss: 0.32 Acc: 89.11%
# TEST:  Loss: 0.21 Acc: 92.98%
#
# Epoch: 150/200    LR: 0.00152
# TRAIN: Loss: 0.32 Acc: 89.19%
# TEST:  Loss: 0.21 Acc: 92.92%
#
# Epoch: 151/200    LR: 0.00146
# TRAIN: Loss: 0.31 Acc: 89.30%
# TEST:  Loss: 0.22 Acc: 92.91%
#
# Epoch: 152/200    LR: 0.00141
# TRAIN: Loss: 0.31 Acc: 89.30%
# TEST:  Loss: 0.21 Acc: 93.01%
#
# Epoch: 153/200    LR: 0.00136
# TRAIN: Loss: 0.30 Acc: 89.53%
# TEST:  Loss: 0.21 Acc: 93.11%
#
# Epoch: 154/200    LR: 0.00130
# TRAIN: Loss: 0.30 Acc: 89.66%
# TEST:  Loss: 0.21 Acc: 92.93%
#
# Epoch: 155/200    LR: 0.00125
# TRAIN: Loss: 0.30 Acc: 89.90%
# TEST:  Loss: 0.21 Acc: 93.22%
#
# Epoch: 156/200    LR: 0.00120
# TRAIN: Loss: 0.30 Acc: 89.85%
# TEST:  Loss: 0.21 Acc: 92.96%
#
# Epoch: 157/200    LR: 0.00115
# TRAIN: Loss: 0.29 Acc: 90.05%
# TEST:  Loss: 0.21 Acc: 93.09%
#
# Epoch: 158/200    LR: 0.00110
# TRAIN: Loss: 0.29 Acc: 90.22%
# TEST:  Loss: 0.21 Acc: 93.26%
#
# Epoch: 159/200    LR: 0.00105
# TRAIN: Loss: 0.29 Acc: 90.29%
# TEST:  Loss: 0.21 Acc: 92.99%
#
# Epoch: 160/200    LR: 0.00100
# TRAIN: Loss: 0.28 Acc: 90.33%
# TEST:  Loss: 0.20 Acc: 93.33%
#
# Epoch: 161/200    LR: 0.00095
# TRAIN: Loss: 0.28 Acc: 90.45%
# TEST:  Loss: 0.21 Acc: 93.35%
#
# Epoch: 162/200    LR: 0.00091
# TRAIN: Loss: 0.28 Acc: 90.54%
# TEST:  Loss: 0.21 Acc: 93.29%
#
# Epoch: 163/200    LR: 0.00086
# TRAIN: Loss: 0.28 Acc: 90.61%
# TEST:  Loss: 0.20 Acc: 93.15%
#
# Epoch: 164/200    LR: 0.00082
# TRAIN: Loss: 0.27 Acc: 90.82%
# TEST:  Loss: 0.20 Acc: 93.47%
#
# Epoch: 165/200    LR: 0.00078
# TRAIN: Loss: 0.27 Acc: 90.79%
# TEST:  Loss: 0.20 Acc: 93.36%
#
# Epoch: 166/200    LR: 0.00074
# TRAIN: Loss: 0.26 Acc: 91.04%
# TEST:  Loss: 0.20 Acc: 93.70%
#
# Epoch: 167/200    LR: 0.00070
# TRAIN: Loss: 0.26 Acc: 91.22%
# TEST:  Loss: 0.20 Acc: 93.34%
#
# Epoch: 168/200    LR: 0.00066
# TRAIN: Loss: 0.27 Acc: 90.92%
# TEST:  Loss: 0.20 Acc: 93.48%
#
# Epoch: 169/200    LR: 0.00062
# TRAIN: Loss: 0.25 Acc: 91.39%
# TEST:  Loss: 0.19 Acc: 93.82%
#
# Epoch: 170/200    LR: 0.00058
# TRAIN: Loss: 0.26 Acc: 91.21%
# TEST:  Loss: 0.19 Acc: 93.81%
#
# Epoch: 171/200    LR: 0.00054
# TRAIN: Loss: 0.25 Acc: 91.37%
# TEST:  Loss: 0.20 Acc: 93.77%
#
# Epoch: 172/200    LR: 0.00051
# TRAIN: Loss: 0.24 Acc: 91.81%
# TEST:  Loss: 0.19 Acc: 93.81%
#
# Epoch: 173/200    LR: 0.00048
# TRAIN: Loss: 0.25 Acc: 91.72%
# TEST:  Loss: 0.19 Acc: 93.62%
#
# Epoch: 174/200    LR: 0.00044
# TRAIN: Loss: 0.25 Acc: 91.62%
# TEST:  Loss: 0.20 Acc: 93.47%
#
# Epoch: 175/200    LR: 0.00041
# TRAIN: Loss: 0.25 Acc: 91.61%
# TEST:  Loss: 0.19 Acc: 93.56%
#
# Epoch: 176/200    LR: 0.00038
# TRAIN: Loss: 0.24 Acc: 91.84%
# TEST:  Loss: 0.19 Acc: 93.78%
#
# Epoch: 177/200    LR: 0.00035
# TRAIN: Loss: 0.24 Acc: 91.82%
# TEST:  Loss: 0.19 Acc: 93.75%
#
# Epoch: 178/200    LR: 0.00032
# TRAIN: Loss: 0.23 Acc: 91.96%
# TEST:  Loss: 0.19 Acc: 93.88%
#
# Epoch: 179/200    LR: 0.00030
# TRAIN: Loss: 0.24 Acc: 91.86%
# TEST:  Loss: 0.19 Acc: 93.93%
#
# Epoch: 180/200    LR: 0.00027
# TRAIN: Loss: 0.23 Acc: 92.13%
# TEST:  Loss: 0.19 Acc: 93.88%
#
# Epoch: 181/200    LR: 0.00024
# TRAIN: Loss: 0.23 Acc: 92.17%
# TEST:  Loss: 0.19 Acc: 93.94%
#
# Epoch: 182/200    LR: 0.00022
# TRAIN: Loss: 0.23 Acc: 92.17%
# TEST:  Loss: 0.19 Acc: 93.86%
#
# Epoch: 183/200    LR: 0.00020
# TRAIN: Loss: 0.23 Acc: 92.28%
# TEST:  Loss: 0.19 Acc: 93.94%
#
# Epoch: 184/200    LR: 0.00018
# TRAIN: Loss: 0.23 Acc: 92.38%
# TEST:  Loss: 0.19 Acc: 94.13%
#
# Epoch: 185/200    LR: 0.00016
# TRAIN: Loss: 0.23 Acc: 92.34%
# TEST:  Loss: 0.19 Acc: 94.03%
#
# Epoch: 186/200    LR: 0.00014
# TRAIN: Loss: 0.23 Acc: 92.29%
# TEST:  Loss: 0.19 Acc: 93.96%
#
# Epoch: 187/200    LR: 0.00012
# TRAIN: Loss: 0.22 Acc: 92.44%
# TEST:  Loss: 0.19 Acc: 94.06%
#
# Epoch: 188/200    LR: 0.00010
# TRAIN: Loss: 0.22 Acc: 92.65%
# TEST:  Loss: 0.19 Acc: 94.00%
#
# Epoch: 189/200    LR: 0.00009
# TRAIN: Loss: 0.22 Acc: 92.44%
# TEST:  Loss: 0.19 Acc: 93.98%
#
# Epoch: 190/200    LR: 0.00007
# TRAIN: Loss: 0.22 Acc: 92.45%
# TEST:  Loss: 0.19 Acc: 93.98%
#
# Epoch: 191/200    LR: 0.00006
# TRAIN: Loss: 0.23 Acc: 92.40%
# TEST:  Loss: 0.19 Acc: 94.00%
#
# Epoch: 192/200    LR: 0.00005
# TRAIN: Loss: 0.22 Acc: 92.63%
# TEST:  Loss: 0.19 Acc: 93.94%
#
# Epoch: 193/200    LR: 0.00004
# TRAIN: Loss: 0.22 Acc: 92.64%
# TEST:  Loss: 0.19 Acc: 94.02%
#
# Epoch: 194/200    LR: 0.00003
# TRAIN: Loss: 0.22 Acc: 92.66%
# TEST:  Loss: 0.19 Acc: 94.14%
#
# Epoch: 195/200    LR: 0.00002
# TRAIN: Loss: 0.22 Acc: 92.66%
# TEST:  Loss: 0.19 Acc: 94.03%
#
# Epoch: 196/200    LR: 0.00002
# TRAIN: Loss: 0.22 Acc: 92.58%
# TEST:  Loss: 0.19 Acc: 93.95%
#
# Epoch: 197/200    LR: 0.00001
# TRAIN: Loss: 0.22 Acc: 92.61%
# TEST:  Loss: 0.19 Acc: 94.09%
#
# Epoch: 198/200    LR: 0.00001
# TRAIN: Loss: 0.21 Acc: 92.79%
# TEST:  Loss: 0.19 Acc: 94.05%
#
# Epoch: 199/200    LR: 0.00000
# TRAIN: Loss: 0.22 Acc: 92.65%
# TEST:  Loss: 0.19 Acc: 94.08%
#
# Epoch: 200/200    LR: 0.00000
# TRAIN: Loss: 0.22 Acc: 92.77%
# TEST:  Loss: 0.19 Acc: 94.03%
# Model saved as ResNetCustom_epoch194_acc94.pth
# Training complete

# %%
# Run inference
try:
    inference('ResNetCustom_epoch194_acc94.pth')
except FileNotFoundError as e:
    print(f'Inference failed: {e}')
# Out:
# Loading data...
# Loading model...
# Running inference...
# Predictions saved as ResNetCustom_epoch194_acc94.csv
