# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/deep-learning-spring-2025-project-1/cifar_test_nolabel.pkl
# /kaggle/input/deep-learning-spring-2025-project-1/cifar-10-python/cifar-10-batches-py/data_batch_1
# /kaggle/input/deep-learning-spring-2025-project-1/cifar-10-python/cifar-10-batches-py/data_batch_2
# /kaggle/input/deep-learning-spring-2025-project-1/cifar-10-python/cifar-10-batches-py/batches.meta
# /kaggle/input/deep-learning-spring-2025-project-1/cifar-10-python/cifar-10-batches-py/test_batch
# /kaggle/input/deep-learning-spring-2025-project-1/cifar-10-python/cifar-10-batches-py/data_batch_3
# /kaggle/input/deep-learning-spring-2025-project-1/cifar-10-python/cifar-10-batches-py/data_batch_5
# /kaggle/input/deep-learning-spring-2025-project-1/cifar-10-python/cifar-10-batches-py/data_batch_4
# /kaggle/input/deep-learning-spring-2025-project-1/cifar-10-python/cifar-10-batches-py/readme.html

# %%
# !git clone https://github.com/timothycao/cifar10_classifier.git
# %cd cifar10_classifier
# Out:
# Cloning into 'cifar10_classifier'...
# remote: Enumerating objects: 84, done.
# remote: Counting objects: 100% (84/84), done.
# remote: Compressing objects: 100% (57/57), done.
# remote: Total 84 (delta 46), reused 62 (delta 24), pack-reused 0 (from 0)
# Receiving objects: 100% (84/84), 21.73 KiB | 4.35 MiB/s, done.
# Resolving deltas: 100% (46/46), done.
# /kaggle/working/cifar10_classifier

# %%
import torch.optim as optim
import torchvision.transforms as transforms
from model import create_model
from train import main as train
from inference import main as inference


# Model parameters
MODEL_NAME = 'ResNetCustom'
BLOCK_TYPE = 'basic'
NUM_BLOCKS_PER_LAYER = [3, 4, 6, 3]
NUM_CHANNELS_PER_LAYER = [31, 62, 124, 248]
KERNEL_SIZE_PER_LAYER = [3, 3, 3, 3]
SKIP_KERNEL_SIZE_PER_LAYER = [1, 1, 1, 1]
EXPANSION = 1
POOL_SIZE = 1


# Training parameters
EPOCHS = 100
TRAIN_BATCH_SIZE = 128
TEST_BATCH_SIZE = 100
AUGMENTATIONS = [
    transforms.RandomHorizontalFlip(p=0.5),
    transforms.RandomCrop(32, padding=4),
    transforms.ColorJitter(brightness=0.2, contrast=0.2, saturation=0.2, hue=0.1),
    transforms.RandomAffine(degrees=10, translate=(0.1, 0.1), scale=(0.8, 1.2)),
    transforms.RandAugment(num_ops=2, magnitude=9),
    transforms.GaussianBlur(kernel_size=3, sigma=(0.1, 2.0)),
    transforms.RandomGrayscale(p=0.2)
]
SAVE_MODE = 'best'  # Options: 'best', 'every'
SAVE_EVERY_N = 1

# Initialize model
try:
    model = create_model(
        name=MODEL_NAME,
        block_type=BLOCK_TYPE,
        blocks_per_layer=NUM_BLOCKS_PER_LAYER,
        channels_per_layer=NUM_CHANNELS_PER_LAYER,
        kernels_per_layer=KERNEL_SIZE_PER_LAYER,
        skip_kernels_per_layer=SKIP_KERNEL_SIZE_PER_LAYER,
        expansion=EXPANSION,
        pool_size=POOL_SIZE
    )
    print('Total model parameters:', sum(p.numel() for p in model.parameters() if p.requires_grad))
except AssertionError as e:
    print(f'Failed to create model: {e}')
    exit(1)
# Out:
# Total model parameters: 4999163

# %%
# Train model
try:
    # Define optimizer
    OPTIMIZER = optim.SGD(model.parameters(), lr=0.01, momentum=0.9, weight_decay=5e-4)
    
    # Define scheduler
    SCHEDULER = optim.lr_scheduler.CosineAnnealingLR(OPTIMIZER, T_max=EPOCHS)
    
    # If no scheduler, set to None
    SCHEDULER = SCHEDULER if 'SCHEDULER' in locals() and SCHEDULER is not None else None

    # train(model, EPOCHS)
    train(model, EPOCHS, train_batch_size=TRAIN_BATCH_SIZE, test_batch_size=TEST_BATCH_SIZE, augmentations=AUGMENTATIONS,
          optimizer=OPTIMIZER, scheduler=SCHEDULER, save=SAVE_MODE, every_n=SAVE_EVERY_N)
except (ValueError, TypeError) as e:
    print(f'Training failed: {e}')
    exit(1)
# Out:
# Total model parameters: 4999163
# Loading data...
# Preprocessing pipeline:
#  Compose(
#     RandomHorizontalFlip(p=0.5)
#     RandomCrop(size=(32, 32), padding=4)
#     ColorJitter(brightness=(0.8, 1.2), contrast=(0.8, 1.2), saturation=(0.8, 1.2), hue=(-0.1, 0.1))
#     RandomAffine(degrees=[-10.0, 10.0], translate=(0.1, 0.1), scale=(0.8, 1.2))
#     RandAugment(num_ops=2, magnitude=9, num_magnitude_bins=31, interpolation=InterpolationMode.NEAREST, fill=None)
#     GaussianBlur(kernel_size=(3, 3), sigma=(0.1, 2.0))
#     RandomGrayscale(p=0.2)
#     ToTensor()
#     Normalize(mean=(0.4914, 0.4822, 0.4465), std=(0.2023, 0.1994, 0.201))
# )
# Files already downloaded and verified
# Files already downloaded and verified
# Initializing model...
# Training model...
#
# Epoch: 1/100      LR: 0.01000
# TRAIN: Loss: 1.96 Acc: 27.59%
# TEST:  Loss: 1.62 Acc: 39.37%
#
# Epoch: 2/100      LR: 0.01000
# TRAIN: Loss: 1.62 Acc: 41.53%
# TEST:  Loss: 1.34 Acc: 52.58%
#
# Epoch: 3/100      LR: 0.00999
# TRAIN: Loss: 1.39 Acc: 50.44%
# TEST:  Loss: 1.23 Acc: 58.47%
#
# Epoch: 4/100      LR: 0.00998
# TRAIN: Loss: 1.25 Acc: 56.33%
# TEST:  Loss: 1.09 Acc: 63.52%
#
# Epoch: 5/100      LR: 0.00996
# TRAIN: Loss: 1.16 Acc: 59.21%
# TEST:  Loss: 1.14 Acc: 63.28%
#
# Epoch: 6/100      LR: 0.00994
# TRAIN: Loss: 1.09 Acc: 61.89%
# TEST:  Loss: 0.87 Acc: 70.24%
#
# Epoch: 7/100      LR: 0.00991
# TRAIN: Loss: 1.04 Acc: 63.62%
# TEST:  Loss: 0.85 Acc: 71.10%
#
# Epoch: 8/100      LR: 0.00988
# TRAIN: Loss: 1.00 Acc: 65.30%
# TEST:  Loss: 0.72 Acc: 75.28%
#
# Epoch: 9/100      LR: 0.00984
# TRAIN: Loss: 0.97 Acc: 66.36%
# TEST:  Loss: 0.90 Acc: 69.87%
#
# Epoch: 10/100     LR: 0.00980
# TRAIN: Loss: 0.93 Acc: 67.25%
# TEST:  Loss: 0.70 Acc: 76.15%
#
# Epoch: 11/100     LR: 0.00976
# TRAIN: Loss: 0.91 Acc: 68.36%
# TEST:  Loss: 0.72 Acc: 75.56%
#
# Epoch: 12/100     LR: 0.00970
# TRAIN: Loss: 0.88 Acc: 69.59%
# TEST:  Loss: 0.75 Acc: 74.98%
#
# Epoch: 13/100     LR: 0.00965
# TRAIN: Loss: 0.86 Acc: 70.22%
# TEST:  Loss: 0.60 Acc: 79.27%
#
# Epoch: 14/100     LR: 0.00959
# TRAIN: Loss: 0.83 Acc: 70.90%
# TEST:  Loss: 0.65 Acc: 78.12%
#
# Epoch: 15/100     LR: 0.00952
# TRAIN: Loss: 0.82 Acc: 71.43%
# TEST:  Loss: 0.58 Acc: 79.95%
#
# Epoch: 16/100     LR: 0.00946
# TRAIN: Loss: 0.81 Acc: 72.04%
# TEST:  Loss: 0.69 Acc: 77.27%
#
# Epoch: 17/100     LR: 0.00938
# TRAIN: Loss: 0.79 Acc: 72.55%
# TEST:  Loss: 0.60 Acc: 79.44%
#
# Epoch: 18/100     LR: 0.00930
# TRAIN: Loss: 0.78 Acc: 73.16%
# TEST:  Loss: 0.51 Acc: 82.86%
#
# Epoch: 19/100     LR: 0.00922
# TRAIN: Loss: 0.76 Acc: 73.55%
# TEST:  Loss: 0.56 Acc: 80.64%
#
# Epoch: 20/100     LR: 0.00914
# TRAIN: Loss: 0.75 Acc: 74.13%
# TEST:  Loss: 0.53 Acc: 82.00%
#
# Epoch: 21/100     LR: 0.00905
# TRAIN: Loss: 0.74 Acc: 74.52%
# TEST:  Loss: 0.52 Acc: 82.48%
#
# Epoch: 22/100     LR: 0.00895
# TRAIN: Loss: 0.72 Acc: 75.06%
# TEST:  Loss: 0.57 Acc: 80.83%
#
# Epoch: 23/100     LR: 0.00885
# TRAIN: Loss: 0.71 Acc: 75.33%
# TEST:  Loss: 0.49 Acc: 83.50%
#
# Epoch: 24/100     LR: 0.00875
# TRAIN: Loss: 0.70 Acc: 75.73%
# TEST:  Loss: 0.47 Acc: 84.53%
#
# Epoch: 25/100     LR: 0.00864
# TRAIN: Loss: 0.69 Acc: 75.97%
# TEST:  Loss: 0.45 Acc: 84.55%
#
# Epoch: 26/100     LR: 0.00854
# TRAIN: Loss: 0.68 Acc: 76.27%
# TEST:  Loss: 0.45 Acc: 84.45%
#
# Epoch: 27/100     LR: 0.00842
# TRAIN: Loss: 0.67 Acc: 76.63%
# TEST:  Loss: 0.49 Acc: 83.81%
#
# Epoch: 28/100     LR: 0.00831
# TRAIN: Loss: 0.66 Acc: 77.29%
# TEST:  Loss: 0.42 Acc: 85.67%
#
# Epoch: 29/100     LR: 0.00819
# TRAIN: Loss: 0.65 Acc: 77.45%
# TEST:  Loss: 0.51 Acc: 82.69%
#
# Epoch: 30/100     LR: 0.00806
# TRAIN: Loss: 0.64 Acc: 77.78%
# TEST:  Loss: 0.42 Acc: 85.70%
#
# Epoch: 31/100     LR: 0.00794
# TRAIN: Loss: 0.64 Acc: 77.92%
# TEST:  Loss: 0.41 Acc: 86.22%
#
# Epoch: 32/100     LR: 0.00781
# TRAIN: Loss: 0.63 Acc: 78.09%
# TEST:  Loss: 0.40 Acc: 86.43%
#
# Epoch: 33/100     LR: 0.00768
# TRAIN: Loss: 0.62 Acc: 78.38%
# TEST:  Loss: 0.44 Acc: 85.35%
#
# Epoch: 34/100     LR: 0.00755
# TRAIN: Loss: 0.61 Acc: 78.80%
# TEST:  Loss: 0.40 Acc: 86.57%
#
# Epoch: 35/100     LR: 0.00741
# TRAIN: Loss: 0.60 Acc: 79.31%
# TEST:  Loss: 0.46 Acc: 84.64%
#
# Epoch: 36/100     LR: 0.00727
# TRAIN: Loss: 0.60 Acc: 79.32%
# TEST:  Loss: 0.38 Acc: 86.94%
#
# Epoch: 37/100     LR: 0.00713
# TRAIN: Loss: 0.59 Acc: 79.73%
# TEST:  Loss: 0.41 Acc: 86.33%
#
# Epoch: 38/100     LR: 0.00699
# TRAIN: Loss: 0.59 Acc: 79.73%
# TEST:  Loss: 0.36 Acc: 87.59%
#
# Epoch: 39/100     LR: 0.00684
# TRAIN: Loss: 0.58 Acc: 79.98%
# TEST:  Loss: 0.39 Acc: 86.76%
#
# Epoch: 40/100     LR: 0.00669
# TRAIN: Loss: 0.57 Acc: 80.26%
# TEST:  Loss: 0.39 Acc: 87.11%
#
# Epoch: 41/100     LR: 0.00655
# TRAIN: Loss: 0.57 Acc: 80.29%
# TEST:  Loss: 0.37 Acc: 87.72%
#
# Epoch: 42/100     LR: 0.00639
# TRAIN: Loss: 0.56 Acc: 80.79%
# TEST:  Loss: 0.39 Acc: 86.74%
#
# Epoch: 43/100     LR: 0.00624
# TRAIN: Loss: 0.55 Acc: 80.95%
# TEST:  Loss: 0.37 Acc: 87.58%
#
# Epoch: 44/100     LR: 0.00609
# TRAIN: Loss: 0.55 Acc: 80.96%
# TEST:  Loss: 0.36 Acc: 87.98%
#
# Epoch: 45/100     LR: 0.00594
# TRAIN: Loss: 0.55 Acc: 81.35%
# TEST:  Loss: 0.35 Acc: 88.24%
#
# Epoch: 46/100     LR: 0.00578
# TRAIN: Loss: 0.54 Acc: 81.31%
# TEST:  Loss: 0.38 Acc: 87.08%
#
# Epoch: 47/100     LR: 0.00563
# TRAIN: Loss: 0.53 Acc: 81.65%
# TEST:  Loss: 0.35 Acc: 88.26%
#
# Epoch: 48/100     LR: 0.00547
# TRAIN: Loss: 0.53 Acc: 81.86%
# TEST:  Loss: 0.35 Acc: 87.99%
#
# Epoch: 49/100     LR: 0.00531
# TRAIN: Loss: 0.52 Acc: 82.15%
# TEST:  Loss: 0.36 Acc: 87.63%
#
# Epoch: 50/100     LR: 0.00516
# TRAIN: Loss: 0.51 Acc: 82.47%
# TEST:  Loss: 0.33 Acc: 88.28%
#
# Epoch: 51/100     LR: 0.00500
# TRAIN: Loss: 0.51 Acc: 82.46%
# TEST:  Loss: 0.31 Acc: 88.92%
#
# Epoch: 52/100     LR: 0.00484
# TRAIN: Loss: 0.50 Acc: 82.54%
# TEST:  Loss: 0.32 Acc: 88.92%
#
# Epoch: 53/100     LR: 0.00469
# TRAIN: Loss: 0.49 Acc: 82.94%
# TEST:  Loss: 0.32 Acc: 88.93%
#
# Epoch: 54/100     LR: 0.00453
# TRAIN: Loss: 0.49 Acc: 82.85%
# TEST:  Loss: 0.33 Acc: 88.49%
#
# Epoch: 55/100     LR: 0.00437
# TRAIN: Loss: 0.48 Acc: 83.26%
# TEST:  Loss: 0.31 Acc: 89.39%
#
# Epoch: 56/100     LR: 0.00422
# TRAIN: Loss: 0.47 Acc: 83.49%
# TEST:  Loss: 0.32 Acc: 88.95%
#
# Epoch: 57/100     LR: 0.00406
# TRAIN: Loss: 0.48 Acc: 83.19%
# TEST:  Loss: 0.31 Acc: 89.32%
#
# Epoch: 58/100     LR: 0.00391
# TRAIN: Loss: 0.46 Acc: 83.94%
# TEST:  Loss: 0.31 Acc: 89.54%
#
# Epoch: 59/100     LR: 0.00376
# TRAIN: Loss: 0.46 Acc: 84.26%
# TEST:  Loss: 0.32 Acc: 89.30%
#
# Epoch: 60/100     LR: 0.00361
# TRAIN: Loss: 0.45 Acc: 84.24%
# TEST:  Loss: 0.30 Acc: 89.79%
#
# Epoch: 61/100     LR: 0.00345
# TRAIN: Loss: 0.45 Acc: 84.24%
# TEST:  Loss: 0.31 Acc: 89.80%
#
# Epoch: 62/100     LR: 0.00331
# TRAIN: Loss: 0.44 Acc: 84.56%
# TEST:  Loss: 0.31 Acc: 89.08%
#
# Epoch: 63/100     LR: 0.00316
# TRAIN: Loss: 0.44 Acc: 84.87%
# TEST:  Loss: 0.30 Acc: 90.24%
#
# Epoch: 64/100     LR: 0.00301
# TRAIN: Loss: 0.44 Acc: 84.99%
# TEST:  Loss: 0.30 Acc: 89.93%
#
# Epoch: 65/100     LR: 0.00287
# TRAIN: Loss: 0.43 Acc: 85.04%
# TEST:  Loss: 0.29 Acc: 90.21%
#
# Epoch: 66/100     LR: 0.00273
# TRAIN: Loss: 0.42 Acc: 85.47%
# TEST:  Loss: 0.28 Acc: 90.38%
#
# Epoch: 67/100     LR: 0.00259
# TRAIN: Loss: 0.42 Acc: 85.69%
# TEST:  Loss: 0.28 Acc: 90.85%
#
# Epoch: 68/100     LR: 0.00245
# TRAIN: Loss: 0.42 Acc: 85.48%
# TEST:  Loss: 0.27 Acc: 90.96%
#
# Epoch: 69/100     LR: 0.00232
# TRAIN: Loss: 0.40 Acc: 86.13%
# TEST:  Loss: 0.28 Acc: 90.85%
#
# Epoch: 70/100     LR: 0.00219
# TRAIN: Loss: 0.40 Acc: 86.02%
# TEST:  Loss: 0.27 Acc: 90.75%
#
# Epoch: 71/100     LR: 0.00206
# TRAIN: Loss: 0.40 Acc: 86.19%
# TEST:  Loss: 0.26 Acc: 91.03%
#
# Epoch: 72/100     LR: 0.00194
# TRAIN: Loss: 0.39 Acc: 86.62%
# TEST:  Loss: 0.26 Acc: 91.07%
#
# Epoch: 73/100     LR: 0.00181
# TRAIN: Loss: 0.39 Acc: 86.55%
# TEST:  Loss: 0.27 Acc: 91.00%
#
# Epoch: 74/100     LR: 0.00169
# TRAIN: Loss: 0.38 Acc: 86.70%
# TEST:  Loss: 0.26 Acc: 91.27%
#
# Epoch: 75/100     LR: 0.00158
# TRAIN: Loss: 0.37 Acc: 86.93%
# TEST:  Loss: 0.25 Acc: 91.88%
#
# Epoch: 76/100     LR: 0.00146
# TRAIN: Loss: 0.37 Acc: 87.25%
# TEST:  Loss: 0.25 Acc: 91.62%
#
# Epoch: 77/100     LR: 0.00136
# TRAIN: Loss: 0.37 Acc: 87.30%
# TEST:  Loss: 0.26 Acc: 91.65%
#
# Epoch: 78/100     LR: 0.00125
# TRAIN: Loss: 0.36 Acc: 87.52%
# TEST:  Loss: 0.25 Acc: 91.78%
#
# Epoch: 79/100     LR: 0.00115
# TRAIN: Loss: 0.36 Acc: 87.71%
# TEST:  Loss: 0.25 Acc: 91.54%
#
# Epoch: 80/100     LR: 0.00105
# TRAIN: Loss: 0.35 Acc: 87.99%
# TEST:  Loss: 0.25 Acc: 91.88%
#
# Epoch: 81/100     LR: 0.00095
# TRAIN: Loss: 0.34 Acc: 88.08%
# TEST:  Loss: 0.24 Acc: 91.96%
#
# Epoch: 82/100     LR: 0.00086
# TRAIN: Loss: 0.34 Acc: 88.21%
# TEST:  Loss: 0.25 Acc: 91.68%
#
# Epoch: 83/100     LR: 0.00078
# TRAIN: Loss: 0.34 Acc: 88.31%
# TEST:  Loss: 0.24 Acc: 92.13%
#
# Epoch: 84/100     LR: 0.00070
# TRAIN: Loss: 0.34 Acc: 88.27%
# TEST:  Loss: 0.23 Acc: 92.36%
#
# Epoch: 85/100     LR: 0.00062
# TRAIN: Loss: 0.33 Acc: 88.47%
# TEST:  Loss: 0.24 Acc: 92.31%
#
# Epoch: 86/100     LR: 0.00054
# TRAIN: Loss: 0.33 Acc: 88.62%
# TEST:  Loss: 0.23 Acc: 92.14%
#
# Epoch: 87/100     LR: 0.00048
# TRAIN: Loss: 0.33 Acc: 88.87%
# TEST:  Loss: 0.24 Acc: 92.03%
#
# Epoch: 88/100     LR: 0.00041
# TRAIN: Loss: 0.32 Acc: 88.95%
# TEST:  Loss: 0.23 Acc: 92.48%
#
# Epoch: 89/100     LR: 0.00035
# TRAIN: Loss: 0.32 Acc: 89.11%
# TEST:  Loss: 0.23 Acc: 92.20%
#
# Epoch: 90/100     LR: 0.00030
# TRAIN: Loss: 0.32 Acc: 89.07%
# TEST:  Loss: 0.23 Acc: 92.30%
#
# Epoch: 91/100     LR: 0.00024
# TRAIN: Loss: 0.32 Acc: 89.07%
# TEST:  Loss: 0.23 Acc: 92.49%
#
# Epoch: 92/100     LR: 0.00020
# TRAIN: Loss: 0.31 Acc: 89.19%
# TEST:  Loss: 0.23 Acc: 92.50%
#
# Epoch: 93/100     LR: 0.00016
# TRAIN: Loss: 0.32 Acc: 89.03%
# TEST:  Loss: 0.23 Acc: 92.61%
#
# Epoch: 94/100     LR: 0.00012
# TRAIN: Loss: 0.31 Acc: 89.13%
# TEST:  Loss: 0.23 Acc: 92.52%
#
# Epoch: 95/100     LR: 0.00009
# TRAIN: Loss: 0.30 Acc: 89.37%
# TEST:  Loss: 0.22 Acc: 92.52%
#
# Epoch: 96/100     LR: 0.00006
# TRAIN: Loss: 0.31 Acc: 89.34%
# TEST:  Loss: 0.23 Acc: 92.52%
#
# Epoch: 97/100     LR: 0.00004
# TRAIN: Loss: 0.31 Acc: 89.39%
# TEST:  Loss: 0.23 Acc: 92.59%
#
# Epoch: 98/100     LR: 0.00002
# TRAIN: Loss: 0.30 Acc: 89.45%
# TEST:  Loss: 0.23 Acc: 92.56%
#
# Epoch: 99/100     LR: 0.00001
# TRAIN: Loss: 0.31 Acc: 89.60%
# TEST:  Loss: 0.23 Acc: 92.57%
#
# Epoch: 100/100    LR: 0.00000
# TRAIN: Loss: 0.31 Acc: 89.28%
# TEST:  Loss: 0.23 Acc: 92.55%
# Model saved as ResNetCustom_epoch93_acc93.pth
# Training complete

# %%
# Run inference
try:
    inference('ResNetCustom_epoch93_acc93.pth')
except FileNotFoundError as e:
    print(f'Inference failed: {e}')
# Out:
# Loading data...
# Loading model...
# Running inference...
# Predictions saved as ResNetCustom_epoch93_acc93.csv
