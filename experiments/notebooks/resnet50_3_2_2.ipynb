# %%
# !git clone https://github.com/timothycao/cifar10_classifier.git
# %cd cifar10_classifier
# Out:
# Cloning into 'cifar10_classifier'...
# remote: Enumerating objects: 93, done.
# remote: Counting objects: 100% (93/93), done.
# remote: Compressing objects: 100% (62/62), done.
# remote: Total 93 (delta 53), reused 68 (delta 28), pack-reused 0 (from 0)
# Receiving objects: 100% (93/93), 24.05 KiB | 3.44 MiB/s, done.
# Resolving deltas: 100% (53/53), done.
# /kaggle/working/cifar10_classifier

# %%
# Resume training

import torch
import torch.optim as optim
import torchvision.transforms as transforms
from train import main as train
from inference import main as inference

model_path = '/kaggle/input/resnet50/resnet50_3_2.pth'

def load_model(model_path, device):
    print(f'Loading model...')
    model = torch.load(model_path, map_location=device, weights_only=False)
    model.to(device)
    if not hasattr(model, 'name'):
        model.name = 'ResNetCustom'
    return model

# Training parameters
EPOCHS = 50
TRAIN_BATCH_SIZE = 128
TEST_BATCH_SIZE = 100
AUGMENTATIONS = [
    transforms.RandomHorizontalFlip(p=0.5),
    transforms.RandomCrop(32, padding=4),
    transforms.ColorJitter(brightness=0.2, contrast=0.2, saturation=0.2, hue=0.1),
    transforms.RandomAffine(degrees=10, translate=(0.1, 0.1), scale=(0.8, 1.2)),
    transforms.RandAugment(num_ops=2, magnitude=12),
    transforms.GaussianBlur(kernel_size=3, sigma=(0.1, 2.0)),
    transforms.RandomGrayscale(p=0.2)
]
CUTMIX_MIXUP = True
SAVE_MODE = 'best'  # Options: 'best', 'every'
SAVE_EVERY_N = 1

# Load model
try:
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    model = load_model(model_path, device)
except AssertionError as e:
    print(f'Failed to load model: {e}')
    exit(1)

# Train model
try:
    OPTIMIZER = optim.SGD(model.parameters(), momentum=0.9, weight_decay=1e-3)
    SCHEDULER = optim.lr_scheduler.OneCycleLR(OPTIMIZER, max_lr=0.0025, total_steps=EPOCHS, final_div_factor=50)

    train(model, EPOCHS, train_batch_size=TRAIN_BATCH_SIZE, test_batch_size=TEST_BATCH_SIZE, augmentations=AUGMENTATIONS,
          cutmix_mixup=CUTMIX_MIXUP, optimizer=OPTIMIZER, scheduler=SCHEDULER, save=SAVE_MODE, every_n=SAVE_EVERY_N)
except (ValueError, TypeError) as e:
    print(f'Training failed: {e}')
    exit(1)
# Out:
# Loading model...
# Total model parameters: 4848027
# Loading data...
# Preprocessing pipeline:
#  Compose(
#     RandomHorizontalFlip(p=0.5)
#     RandomCrop(size=(32, 32), padding=4)
#     ColorJitter(brightness=(0.8, 1.2), contrast=(0.8, 1.2), saturation=(0.8, 1.2), hue=(-0.1, 0.1))
#     RandomAffine(degrees=[-10.0, 10.0], translate=(0.1, 0.1), scale=(0.8, 1.2))
#     RandAugment(num_ops=2, magnitude=12, num_magnitude_bins=31, interpolation=InterpolationMode.NEAREST, fill=None)
#     GaussianBlur(kernel_size=(3, 3), sigma=(0.1, 2.0))
#     RandomGrayscale(p=0.2)
#     ToTensor()
#     Normalize(mean=(0.4914, 0.4822, 0.4465), std=(0.2023, 0.1994, 0.201))
# )
# Files already downloaded and verified
# Files already downloaded and verified
# Initializing model...
# Training model...
#
# Epoch: 1/50       LR: 0.00010
# TRAIN: Loss: 1.63 Acc: 65.45%
# TEST:  Loss: 0.36 Acc: 91.12%
#
# Epoch: 2/50       LR: 0.00013
# TRAIN: Loss: 1.38 Acc: 67.31%
# TEST:  Loss: 0.33 Acc: 92.91%
#
# Epoch: 3/50       LR: 0.00022
# TRAIN: Loss: 1.33 Acc: 69.58%
# TEST:  Loss: 0.33 Acc: 93.50%
#
# Epoch: 4/50       LR: 0.00036
# TRAIN: Loss: 1.34 Acc: 69.11%
# TEST:  Loss: 0.31 Acc: 93.74%
#
# Epoch: 5/50       LR: 0.00055
# TRAIN: Loss: 1.34 Acc: 69.01%
# TEST:  Loss: 0.34 Acc: 93.36%
#
# Epoch: 6/50       LR: 0.00078
# TRAIN: Loss: 1.34 Acc: 68.50%
# TEST:  Loss: 0.33 Acc: 93.51%
#
# Epoch: 7/50       LR: 0.00103
# TRAIN: Loss: 1.29 Acc: 70.76%
# TRAIN: Loss: 1.28 Acc: 69.15%
# TEST:  Loss: 0.34 Acc: 93.82%
#
# Epoch: 31/50      LR: 0.00142
# TRAIN: Loss: 1.30 Acc: 68.91%
# TEST:  Loss: 0.39 Acc: 93.36%
#
# Epoch: 32/50      LR: 0.00131
# TRAIN: Loss: 1.23 Acc: 72.06%
# TEST:  Loss: 0.34 Acc: 93.26%
#
# Epoch: 33/50      LR: 0.00119
# TRAIN: Loss: 1.26 Acc: 71.13%
# TEST:  Loss: 0.36 Acc: 93.94%
#
# Epoch: 34/50      LR: 0.00108
# TRAIN: Loss: 1.23 Acc: 71.02%
# TEST:  Loss: 0.34 Acc: 93.93%
#
# Epoch: 35/50      LR: 0.00097
# TRAIN: Loss: 1.23 Acc: 71.29%
# TEST:  Loss: 0.37 Acc: 93.39%
#
# Epoch: 36/50      LR: 0.00087
# TRAIN: Loss: 1.26 Acc: 71.54%
# TEST:  Loss: 0.29 Acc: 94.10%
#
# Epoch: 37/50      LR: 0.00076
# TRAIN: Loss: 1.26 Acc: 70.74%
# TEST:  Loss: 0.39 Acc: 93.41%
#
# Epoch: 38/50      LR: 0.00066
# TRAIN: Loss: 1.23 Acc: 71.15%
# TEST:  Loss: 0.32 Acc: 94.07%
#
# Epoch: 39/50      LR: 0.00056
# TRAIN: Loss: 1.26 Acc: 70.56%
# TEST:  Loss: 0.28 Acc: 94.41%
#
# Epoch: 40/50      LR: 0.00047
# TRAIN: Loss: 1.24 Acc: 71.71%
# TEST:  Loss: 0.40 Acc: 93.98%
#
# Epoch: 41/50      LR: 0.00039
# TRAIN: Loss: 1.22 Acc: 71.16%
# TEST:  Loss: 0.42 Acc: 94.03%
#
# Epoch: 42/50      LR: 0.00031
# TRAIN: Loss: 1.24 Acc: 70.94%
# TEST:  Loss: 0.37 Acc: 94.02%
#
# Epoch: 43/50      LR: 0.00024
# TRAIN: Loss: 1.22 Acc: 72.60%
# TEST:  Loss: 0.27 Acc: 94.58%
#
# Epoch: 44/50      LR: 0.00018
# TRAIN: Loss: 1.22 Acc: 72.49%
# TEST:  Loss: 0.35 Acc: 94.46%
#
# Epoch: 45/50      LR: 0.00013
# TRAIN: Loss: 1.22 Acc: 72.47%
# TEST:  Loss: 0.28 Acc: 94.70%
#
# Epoch: 46/50      LR: 0.00008
# TRAIN: Loss: 1.19 Acc: 73.66%
# TEST:  Loss: 0.32 Acc: 94.62%
#
# Epoch: 47/50      LR: 0.00005
# TRAIN: Loss: 1.20 Acc: 73.12%
# TEST:  Loss: 0.32 Acc: 94.60%
#
# Epoch: 48/50      LR: 0.00002
# TRAIN: Loss: 1.19 Acc: 72.78%
# TEST:  Loss: 0.28 Acc: 94.71%
#
# Epoch: 49/50      LR: 0.00001
# TRAIN: Loss: 1.21 Acc: 72.40%
# TEST:  Loss: 0.33 Acc: 94.51%
#
# Epoch: 50/50      LR: 0.00000
# TRAIN: Loss: 1.20 Acc: 73.33%
# TEST:  Loss: 0.31 Acc: 94.63%
# Model saved as ResNetCustom_epoch48_acc95.pth
# Training complete

# %%
# Run inference
try:
    inference('ResNetCustom_epoch48_acc95.pth')
except FileNotFoundError as e:
    print(f'Inference failed: {e}')
# Out:
# Loading data...
# Loading model...
# Running inference...
# Predictions saved as ResNetCustom_epoch48_acc95.csv
