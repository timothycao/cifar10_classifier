# %%
# !git clone https://github.com/timothycao/cifar10_classifier.git
# %cd cifar10_classifier
# Out:
# Cloning into 'cifar10_classifier'...
# remote: Enumerating objects: 98, done.
# remote: Counting objects: 100% (98/98), done.
# remote: Compressing objects: 100% (67/67), done.
# remote: Total 98 (delta 56), reused 70 (delta 28), pack-reused 0 (from 0)
# Receiving objects: 100% (98/98), 25.00 KiB | 4.17 MiB/s, done.
# Resolving deltas: 100% (56/56), done.
# /kaggle/working/cifar10_classifier

# %%
# Resume training

import torch
import torch.optim as optim
import torchvision.transforms as transforms
from train import main as train
from inference import main as inference

model_path = '/kaggle/input/resnet50/resnet50_3_2.pth'

def load_model(model_path, device):
    print(f'Loading model...')
    model = torch.load(model_path, map_location=device, weights_only=False)
    model.to(device)
    if not hasattr(model, 'name'):
        model.name = 'ResNetCustom'
    return model

# Training parameters
EPOCHS = 100
TRAIN_BATCH_SIZE = 128
TEST_BATCH_SIZE = 100
AUGMENTATIONS = [
    transforms.RandomHorizontalFlip(p=0.5),
    transforms.RandomCrop(32, padding=4),
    transforms.ColorJitter(brightness=0.2, contrast=0.2, saturation=0.2, hue=0.1),
    transforms.RandomAffine(degrees=10, translate=(0.1, 0.1), scale=(0.8, 1.2)),
    transforms.RandAugment(num_ops=2, magnitude=12),
    transforms.GaussianBlur(kernel_size=3, sigma=(0.1, 2.0)),
    transforms.RandomGrayscale(p=0.2)
]
CUTMIX_MIXUP = True
SAVE_MODE = 'best'  # Options: 'best', 'every'
SAVE_EVERY_N = 1

# Load model
try:
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    model = load_model(model_path, device)
except AssertionError as e:
    print(f'Failed to load model: {e}')
    exit(1)

# Train model
try:
    OPTIMIZER = optim.SGD(model.parameters(), momentum=0.9, weight_decay=1e-3)
    SCHEDULER = optim.lr_scheduler.OneCycleLR(OPTIMIZER, max_lr=0.002, total_steps=EPOCHS, final_div_factor=50)

    train(model, EPOCHS, train_batch_size=TRAIN_BATCH_SIZE, test_batch_size=TEST_BATCH_SIZE, augmentations=AUGMENTATIONS,
          cutmix_mixup=CUTMIX_MIXUP, optimizer=OPTIMIZER, scheduler=SCHEDULER, save=SAVE_MODE, every_n=SAVE_EVERY_N)
except (ValueError, TypeError) as e:
    print(f'Training failed: {e}')
    exit(1)
# Out:
# Loading model...
# Total model parameters: 4848027
# Loading data...
# Preprocessing pipeline:
#  Compose(
#     RandomHorizontalFlip(p=0.5)
#     RandomCrop(size=(32, 32), padding=4)
#     ColorJitter(brightness=(0.8, 1.2), contrast=(0.8, 1.2), saturation=(0.8, 1.2), hue=(-0.1, 0.1))
#     RandomAffine(degrees=[-10.0, 10.0], translate=(0.1, 0.1), scale=(0.8, 1.2))
#     RandAugment(num_ops=2, magnitude=12, num_magnitude_bins=31, interpolation=InterpolationMode.NEAREST, fill=None)
#     GaussianBlur(kernel_size=(3, 3), sigma=(0.1, 2.0))
#     RandomGrayscale(p=0.2)
#     ToTensor()
#     Normalize(mean=(0.4914, 0.4822, 0.4465), std=(0.2023, 0.1994, 0.201))
# )
# Files already downloaded and verified
# Files already downloaded and verified
#
# TRAIN: Loss: 1.22 Acc: 72.00%
# TEST:  Loss: 0.37 Acc: 93.87%
#
# Epoch: 64/100     LR: 0.00105
# TRAIN: Loss: 1.24 Acc: 71.58%
# TEST:  Loss: 0.31 Acc: 93.84%
#
# Epoch: 65/100     LR: 0.00100
# TRAIN: Loss: 1.21 Acc: 72.44%
# TEST:  Loss: 0.35 Acc: 93.66%
#
# Epoch: 66/100     LR: 0.00096
# TRAIN: Loss: 1.23 Acc: 71.87%
# TEST:  Loss: 0.31 Acc: 94.01%
#
# Epoch: 67/100     LR: 0.00091
# TRAIN: Loss: 1.19 Acc: 72.71%
# TEST:  Loss: 0.35 Acc: 93.43%
#
# Epoch: 68/100     LR: 0.00087
# TRAIN: Loss: 1.22 Acc: 71.15%
# TEST:  Loss: 0.37 Acc: 93.81%
#
# Epoch: 69/100     LR: 0.00082
# TRAIN: Loss: 1.21 Acc: 71.34%
# TEST:  Loss: 0.33 Acc: 93.98%
#
# Epoch: 70/100     LR: 0.00078
# TRAIN: Loss: 1.20 Acc: 72.42%
# TEST:  Loss: 0.30 Acc: 94.11%
#
# Epoch: 71/100     LR: 0.00073
# TRAIN: Loss: 1.25 Acc: 71.32%
# TEST:  Loss: 0.36 Acc: 94.13%
#
# Epoch: 72/100     LR: 0.00069
# TRAIN: Loss: 1.22 Acc: 71.57%
# TEST:  Loss: 0.31 Acc: 94.23%
#
# Epoch: 73/100     LR: 0.00065
# TRAIN: Loss: 1.22 Acc: 71.82%
# TEST:  Loss: 0.39 Acc: 93.87%
#
# Epoch: 74/100     LR: 0.00061
# TRAIN: Loss: 1.22 Acc: 71.33%
# TEST:  Loss: 0.36 Acc: 93.76%
#
# Epoch: 75/100     LR: 0.00057
# TRAIN: Loss: 1.22 Acc: 72.12%
# TEST:  Loss: 0.29 Acc: 94.47%
#
# Epoch: 76/100     LR: 0.00053
# TRAIN: Loss: 1.21 Acc: 72.77%
# TEST:  Loss: 0.33 Acc: 94.43%
#
# Epoch: 77/100     LR: 0.00049
# TRAIN: Loss: 1.22 Acc: 71.72%
# TEST:  Loss: 0.30 Acc: 94.47%
#
# Epoch: 78/100     LR: 0.00045
# TRAIN: Loss: 1.20 Acc: 73.13%
# TEST:  Loss: 0.40 Acc: 94.08%
#
# Epoch: 79/100     LR: 0.00041
# TRAIN: Loss: 1.18 Acc: 74.28%
# TEST:  Loss: 0.32 Acc: 94.35%
#
# Epoch: 80/100     LR: 0.00038
# TRAIN: Loss: 1.17 Acc: 73.78%
# TEST:  Loss: 0.35 Acc: 94.37%
#
# Epoch: 81/100     LR: 0.00034
# TRAIN: Loss: 1.20 Acc: 73.45%
# TEST:  Loss: 0.31 Acc: 94.29%
#
# Epoch: 82/100     LR: 0.00031
# TRAIN: Loss: 1.21 Acc: 72.32%
# TEST:  Loss: 0.37 Acc: 94.25%
#
# Epoch: 83/100     LR: 0.00028
# TRAIN: Loss: 1.19 Acc: 73.70%
# TEST:  Loss: 0.41 Acc: 93.83%
#
# Epoch: 84/100     LR: 0.00025
# TRAIN: Loss: 1.21 Acc: 72.01%
# TEST:  Loss: 0.38 Acc: 94.16%
#
# Epoch: 85/100     LR: 0.00022
# TRAIN: Loss: 1.16 Acc: 73.77%
# TEST:  Loss: 0.38 Acc: 94.28%
#
# Epoch: 86/100     LR: 0.00019
# TRAIN: Loss: 1.17 Acc: 74.92%
# TEST:  Loss: 0.33 Acc: 94.55%
#
# Epoch: 87/100     LR: 0.00017
# TRAIN: Loss: 1.20 Acc: 72.87%
# TEST:  Loss: 0.34 Acc: 94.49%
#
# Epoch: 88/100     LR: 0.00014
# TRAIN: Loss: 1.19 Acc: 72.73%
# TEST:  Loss: 0.30 Acc: 94.61%
#
# Epoch: 89/100     LR: 0.00012
# TRAIN: Loss: 1.17 Acc: 74.52%
# TEST:  Loss: 0.35 Acc: 94.68%
#
# Epoch: 90/100     LR: 0.00010
# TRAIN: Loss: 1.17 Acc: 73.80%
# TEST:  Loss: 0.34 Acc: 94.71%
#
# Epoch: 91/100     LR: 0.00008
# TRAIN: Loss: 1.19 Acc: 73.08%
# TEST:  Loss: 0.32 Acc: 94.74%
#
# Epoch: 92/100     LR: 0.00007
# TRAIN: Loss: 1.14 Acc: 75.82%
# TEST:  Loss: 0.29 Acc: 94.91%
#
# Epoch: 93/100     LR: 0.00005
# TRAIN: Loss: 1.14 Acc: 74.44%
# TEST:  Loss: 0.30 Acc: 94.87%
#
# Epoch: 94/100     LR: 0.00004
# TRAIN: Loss: 1.18 Acc: 73.86%
# TEST:  Loss: 0.32 Acc: 94.77%
#
# Epoch: 95/100     LR: 0.00003
# TRAIN: Loss: 1.16 Acc: 73.96%
# TEST:  Loss: 0.30 Acc: 94.98%
#
# Epoch: 96/100     LR: 0.00002
# TRAIN: Loss: 1.15 Acc: 75.40%
# TEST:  Loss: 0.36 Acc: 94.80%
#
# Epoch: 97/100     LR: 0.00001
# TRAIN: Loss: 1.16 Acc: 74.16%
# TEST:  Loss: 0.32 Acc: 94.92%
#
# Epoch: 98/100     LR: 0.00001
# TRAIN: Loss: 1.20 Acc: 72.97%
# TEST:  Loss: 0.36 Acc: 94.78%
#
# Epoch: 99/100     LR: 0.00000
# TRAIN: Loss: 1.17 Acc: 74.15%
# TEST:  Loss: 0.36 Acc: 94.72%
#
# Epoch: 100/100    LR: 0.00000
# TRAIN: Loss: 1.18 Acc: 73.54%
# TEST:  Loss: 0.36 Acc: 94.74%
# Model saved as ResNetCustom_epoch95_acc95.pth
# Training complete

# %%
# Run inference
try:
    inference('ResNetCustom_epoch95_acc95.pth')
except FileNotFoundError as e:
    print(f'Inference failed: {e}')
# Out:
# Loading data...
# Loading model...
# Running inference...
# Predictions saved as ResNetCustom_epoch95_acc95.csv
